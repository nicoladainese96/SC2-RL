# %%
import sys
sys.path.insert(0, "../")
from Utils import utils, plot
from Utils.train_batched_A2C import *
from Utils.A2C_inspection import *
from Utils.inspection_plots import *
import AC_modules.Networks as net
from AC_modules.BatchedA2C import SpatialA2C

import torch
import numpy as np
import matplotlib.pyplot as plt
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-cb9b6219927a> in <module>
#       2 sys.path.insert(0, "../")
#       3 from Utils import utils, plot
# ----> 4 from Utils.train_batched_A2C import *
#       5 from Utils.A2C_inspection import *
#       6 from Utils.inspection_plots import *
#
# /m/home/home9/94/dainesn1/unix/Workdir/SC2-RL/Utils/train_batched_A2C.py in <module>
#      10 from Utils.A2C_inspection import *
#      11
# ---> 12 from pysc2.env import sc2_env
#      13 from pysc2.lib import features
#      14 from pysc2.lib import actions
#
# ~/.local/lib/python3.7/site-packages/pysc2/env/sc2_env.py in <module>
#      33 from pysc2.lib import metrics
#      34 from pysc2.lib import portspicker
# ---> 35 from pysc2.lib import renderer_human
#      36 from pysc2.lib import run_parallel
#      37 from pysc2.lib import stopwatch
#
# ~/.local/lib/python3.7/site-packages/pysc2/lib/renderer_human.py in <module>
#      45 from pysc2.lib import transform
#      46
# ---> 47 from pysc2.lib import video_writer
#      48 from s2clientprotocol import error_pb2 as sc_err
#      49 from s2clientprotocol import raw_pb2 as sc_raw
#
# ~/.local/lib/python3.7/site-packages/pysc2/lib/video_writer.py in <module>
#      18 from __future__ import print_function
#      19
# ---> 20 import skvideo.io
#      21
#      22
#
# ~/.local/lib/python3.7/site-packages/skvideo/__init__.py in <module>
#       1 __version__ = "1.1.10"
#       2
# ----> 3 from .utils import check_output, where
#       4 import os
#       5 import warnings
#
# ~/.local/lib/python3.7/site-packages/skvideo/utils/__init__.py in <module>
#       9 import numpy as np
#      10 from .edge import canny
# ---> 11 from .stpyr import SpatialSteerablePyramid
#      12 from .mscn import compute_image_mscn_transform, gen_gauss_window
#      13 from .stats import ggd_features, aggd_features, paired_product
#
# ~/.local/lib/python3.7/site-packages/skvideo/utils/stpyr.py in <module>
#       1 import numpy as np
#       2 import scipy.misc as sc
# ----> 3 import scipy.signal
#       4 import scipy.io
#       5
#
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/scipy/signal/__init__.py in <module>
#     305 from .spectral import *
#     306 from .wavelets import *
# --> 307 from ._peak_finding import *
#     308 from .windows import get_window  # keep this one in signal namespace
#     309
#
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/scipy/signal/_peak_finding.py in <module>
#       9 from scipy._lib.six import xrange
#      10 from scipy.signal.wavelets import cwt, ricker
# ---> 11 from scipy.stats import scoreatpercentile
#      12
#      13 from ._peak_finding_utils import (
#
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/scipy/stats/__init__.py in <module>
#     384 from . import mstats
#     385 from .contingency import chi2_contingency
# --> 386 from ._multivariate import *
#     387
#     388 __all__ = [s for s in dir() if not s.startswith("_")]  # Remove dunders.
#
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/importlib/_bootstrap_external.py in get_data(self, path)
#
# KeyboardInterrupt:

# %% [markdown]
# # Load training session to inspect

# %%
load_dir = "Results/MoveToBeacon/"
queries = ['WUAY.npy']
train_dict = utils.load_session(load_dir, queries)

# %%
game_params = train_dict['game_params']
HPs = train_dict['HPs']
score = train_dict['score']
losses = train_dict['losses']
keywords = train_dict['keywords']
ID = keywords[-1]
print("HPs: ", HPs)

# %%
plot.plot_bA2C_session(score, losses, unroll_length=240, test_interval=10, moving_average=False, average_window=10)

# %% [markdown]
# # Update variables visualization

# %% [markdown]
# First of all search for the step nearest to the point that we want to inspect

# %%
n = 18
step_idx =  0 + n*1200
step_idx
# Out:
# 21600

# %%
load_dir = "Results/MoveToBeacon/Inspection/"
PID = "ULLM"
step_idx = step_idx
insp_dict = np.load(load_dir+PID+"_"+str(step_idx)+".npy", allow_pickle=True).item()

# %%
insp_dict.keys()
# Out:
# dict_keys(['state_traj', 'rewards', 'action_distr', 'action_sel', 'queue_distr', 'queue_sel', 'selectall_distr', 'selectall_sel', 'spatial_distr', 'spatial_sel', 'values', 'trg_values', 'critic_losses', 'advantages', 'actor_losses'])

# %%
plot_update_curves(insp_dict)

# %%
#plot_update_curves(insp_dict, 55, 90)

# %% [markdown]
# # Frame by frame visualization

# %% [markdown]
# Coordinates:
# 1. Map works with y and then x
# 2. Actions work with x and then y

# %%
insp_dict.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cf982070380e> in <module>
# ----> 1 insp_dict.keys()
#
# NameError: name 'insp_dict' is not defined

# %%
#for t in range(len(insp_dict['state_traj'])):
for t in range(50):
    print_action_info(insp_dict, t)
    plot_screen_and_decision(insp_dict, t)
# Out:
# Step 0
# _NO_OP: 	22.56
# _SELECT_ARMY:  77.44 - _SELECT_ALL: 1.61
# _MOVE_SCREEN:   0.00 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [0]
# State value: 7.8232
# Move advantage: -0.6589
# Step 1
# _NO_OP: 	22.56
# _SELECT_ARMY:  77.44 - _SELECT_ALL: 1.61
# _MOVE_SCREEN:   0.00 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [0]
# State value: 7.8232
# Move advantage: -0.6151
# Step 2
# _NO_OP: 	22.56
# _SELECT_ARMY:  77.44 - _SELECT_ALL: 1.61
# _MOVE_SCREEN:   0.00 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.8232
# Move advantage: -0.5365
# Step 3
# _NO_OP: 	12.27
# _SELECT_ARMY:  42.11 - _SELECT_ALL: 1.61
# _MOVE_SCREEN:   45.63 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.8232
# Move advantage: 0.3079
# Step 4
# _NO_OP: 	12.27
# _SELECT_ARMY:  42.11 - _SELECT_ALL: 1.61
# _MOVE_SCREEN:   45.63 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.8232
# Move advantage: 0.0806
# Step 5
# _NO_OP: 	12.27
# _SELECT_ARMY:  42.11 - _SELECT_ALL: 1.61
# _MOVE_SCREEN:   45.63 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(29,39)
# Action selected:  [2]
# State value: 7.8232
# Move advantage: 0.1001
# Step 6
# _NO_OP: 	12.30
# _SELECT_ARMY:  42.04 - _SELECT_ALL: 1.59
# _MOVE_SCREEN:   45.66 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.8395
# Move advantage: 0.0928
# Step 7
# _NO_OP: 	12.20
# _SELECT_ARMY:  42.22 - _SELECT_ALL: 1.55
# _MOVE_SCREEN:   45.58 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [0]
# State value: 7.8887
# Move advantage: 0.0617
# Step 8
# _NO_OP: 	12.16
# _SELECT_ARMY:  42.75 - _SELECT_ALL: 1.51
# _MOVE_SCREEN:   45.10 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.9373
# Move advantage: 0.0314
# Step 9
# _NO_OP: 	12.21
# _SELECT_ARMY:  42.85 - _SELECT_ALL: 1.54
# _MOVE_SCREEN:   44.94 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.8997
# Move advantage: 0.0875
# Step 10
# _NO_OP: 	11.99
# _SELECT_ARMY:  43.34 - _SELECT_ALL: 1.44
# _MOVE_SCREEN:   44.67 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [0]
# State value: 8.0255
# Move advantage: 0.0145
# Step 11
# _NO_OP: 	11.77
# _SELECT_ARMY:  43.19 - _SELECT_ALL: 1.38
# _MOVE_SCREEN:   45.04 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 8.1048
# Move advantage: 0.0216
# Step 12
# _NO_OP: 	11.70
# _SELECT_ARMY:  42.90 - _SELECT_ALL: 1.36
# _MOVE_SCREEN:   45.40 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(30,40)
# Action selected:  [2]
# State value: 8.1352
# Move advantage: 0.0417
# Step 13
# _NO_OP: 	12.70
# _SELECT_ARMY:  41.84 - _SELECT_ALL: 1.75
# _MOVE_SCREEN:   45.45 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.6668
# Move advantage: -0.4299
# Step 14
# _NO_OP: 	12.84
# _SELECT_ARMY:  41.69 - _SELECT_ALL: 1.78
# _MOVE_SCREEN:   45.47 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(10,22)
# Action selected:  [2]
# State value: 7.6270
# Move advantage: -0.3515
# Step 15
# _NO_OP: 	12.76
# _SELECT_ARMY:  41.81 - _SELECT_ALL: 1.72
# _MOVE_SCREEN:   45.42 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [0]
# State value: 7.6967
# Move advantage: -0.4002
# Step 16
# _NO_OP: 	12.93
# _SELECT_ARMY:  42.09 - _SELECT_ALL: 1.70
# _MOVE_SCREEN:   44.99 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.7229
# Move advantage: -0.4317
# Step 17
# _NO_OP: 	12.93
# _SELECT_ARMY:  42.59 - _SELECT_ALL: 1.71
# _MOVE_SCREEN:   44.48 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.7127
# Move advantage: -0.4325
# Step 18
# _NO_OP: 	12.96
# _SELECT_ARMY:  42.27 - _SELECT_ALL: 1.76
# _MOVE_SCREEN:   44.77 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.6572
# Move advantage: -0.3917
# Step 19
# _NO_OP: 	12.91
# _SELECT_ARMY:  41.93 - _SELECT_ALL: 1.74
# _MOVE_SCREEN:   45.16 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.6756
# Move advantage: -0.4359
# Step 20
# _NO_OP: 	12.73
# _SELECT_ARMY:  41.69 - _SELECT_ALL: 1.70
# _MOVE_SCREEN:   45.58 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(10,21)
# Action selected:  [2]
# State value: 7.7182
# Move advantage: -0.4826
# Step 21
# _NO_OP: 	12.54
# _SELECT_ARMY:  41.77 - _SELECT_ALL: 1.63
# _MOVE_SCREEN:   45.69 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(12,22)
# Action selected:  [2]
# State value: 7.8032
# Move advantage: -0.5329
# Step 22
# _NO_OP: 	12.54
# _SELECT_ARMY:  41.89 - _SELECT_ALL: 1.62
# _MOVE_SCREEN:   45.57 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(11,23)
# Action selected:  [2]
# State value: 7.8144
# Move advantage: -0.4962
# Step 23
# _NO_OP: 	13.34
# _SELECT_ARMY:  41.94 - _SELECT_ALL: 1.90
# _MOVE_SCREEN:   44.72 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.5150
# Move advantage: -0.3227
# Step 24
# _NO_OP: 	13.38
# _SELECT_ARMY:  41.78 - _SELECT_ALL: 1.90
# _MOVE_SCREEN:   44.83 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.5171
# Move advantage: -0.4130
# Step 25
# _NO_OP: 	13.40
# _SELECT_ARMY:  41.43 - _SELECT_ALL: 1.91
# _MOVE_SCREEN:   45.18 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.5062
# Move advantage: -0.3755
# Step 26
# _NO_OP: 	13.40
# _SELECT_ARMY:  41.43 - _SELECT_ALL: 1.91
# _MOVE_SCREEN:   45.18 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.5062
# Move advantage: -0.3877
# Step 27
# _NO_OP: 	13.40
# _SELECT_ARMY:  41.43 - _SELECT_ALL: 1.91
# _MOVE_SCREEN:   45.18 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.5062
# Move advantage: -0.3712
# Step 28
# _NO_OP: 	13.40
# _SELECT_ARMY:  41.43 - _SELECT_ALL: 1.91
# _MOVE_SCREEN:   45.18 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(56,9)
# Action selected:  [2]
# State value: 7.5062
# Move advantage: -0.3508
# Step 29
# _NO_OP: 	13.49
# _SELECT_ARMY:  42.06 - _SELECT_ALL: 1.87
# _MOVE_SCREEN:   44.45 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.5480
# Move advantage: -0.2652
# Step 30
# _NO_OP: 	13.30
# _SELECT_ARMY:  42.15 - _SELECT_ALL: 1.79
# _MOVE_SCREEN:   44.56 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.6305
# Move advantage: -0.2042
# Step 31
# _NO_OP: 	12.97
# _SELECT_ARMY:  42.26 - _SELECT_ALL: 1.75
# _MOVE_SCREEN:   44.77 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.6689
# Move advantage: -0.1515
# Step 32
# _NO_OP: 	12.64
# _SELECT_ARMY:  43.67 - _SELECT_ALL: 1.69
# _MOVE_SCREEN:   43.69 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(57,9)
# Action selected:  [2]
# State value: 7.7311
# Move advantage: 0.6716
# Step 33
# _NO_OP: 	12.74
# _SELECT_ARMY:  44.61 - _SELECT_ALL: 1.66
# _MOVE_SCREEN:   42.66 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(56,9)
# Action selected:  [2]
# State value: 7.7671
# Move advantage: 0.2801
# Step 34
# _NO_OP: 	13.00
# _SELECT_ARMY:  44.08 - _SELECT_ALL: 1.65
# _MOVE_SCREEN:   42.92 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.7813
# Move advantage: 0.2927
# Step 35
# _NO_OP: 	13.03
# _SELECT_ARMY:  42.52 - _SELECT_ALL: 1.67
# _MOVE_SCREEN:   44.45 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.7634
# Move advantage: 0.3412
# Step 36
# _NO_OP: 	13.05
# _SELECT_ARMY:  41.69 - _SELECT_ALL: 1.69
# _MOVE_SCREEN:   45.25 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(56,9)
# Action selected:  [2]
# State value: 7.7383
# Move advantage: 0.4241
# Step 37
# _NO_OP: 	13.11
# _SELECT_ARMY:  41.45 - _SELECT_ALL: 1.72
# _MOVE_SCREEN:   45.43 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.7086
# Move advantage: 0.4519
# Step 38
# _NO_OP: 	13.22
# _SELECT_ARMY:  41.96 - _SELECT_ALL: 1.76
# _MOVE_SCREEN:   44.82 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.6652
# Move advantage: 0.4302
# Step 39
# _NO_OP: 	13.37
# _SELECT_ARMY:  42.45 - _SELECT_ALL: 1.77
# _MOVE_SCREEN:   44.19 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [0]
# State value: 7.6481
# Move advantage: 0.4792
# Step 40
# _NO_OP: 	13.29
# _SELECT_ARMY:  42.54 - _SELECT_ALL: 1.75
# _MOVE_SCREEN:   44.17 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(56,6)
# Action selected:  [2]
# State value: 7.6786
# Move advantage: 0.5388
# Step 41
# _NO_OP: 	13.25
# _SELECT_ARMY:  41.72 - _SELECT_ALL: 1.70
# _MOVE_SCREEN:   45.03 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.7249
# Move advantage: 0.5690
# Step 42
# _NO_OP: 	12.95
# _SELECT_ARMY:  41.64 - _SELECT_ALL: 1.65
# _MOVE_SCREEN:   45.41 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(54,10)
# Action selected:  [2]
# State value: 7.7833
# Move advantage: 1.3626
# Step 43
# _NO_OP: 	13.17
# _SELECT_ARMY:  41.44 - _SELECT_ALL: 1.75
# _MOVE_SCREEN:   45.39 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.6654
# Move advantage: 0.2044
# Step 44
# _NO_OP: 	13.17
# _SELECT_ARMY:  41.47 - _SELECT_ALL: 1.73
# _MOVE_SCREEN:   45.36 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [0]
# State value: 7.6876
# Move advantage: 0.1878
# Step 45
# _NO_OP: 	13.30
# _SELECT_ARMY:  41.35 - _SELECT_ALL: 1.76
# _MOVE_SCREEN:   45.36 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(39,11)
# Action selected:  [2]
# State value: 7.6623
# Move advantage: 0.2466
# Step 46
# _NO_OP: 	13.20
# _SELECT_ARMY:  41.51 - _SELECT_ALL: 1.74
# _MOVE_SCREEN:   45.28 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(37,12)
# Action selected:  [2]
# State value: 7.6720
# Move advantage: 0.3363
# Step 47
# _NO_OP: 	13.12
# _SELECT_ARMY:  41.50 - _SELECT_ALL: 1.73
# _MOVE_SCREEN:   45.38 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.6863
# Move advantage: 0.4332
# Step 48
# _NO_OP: 	12.94
# _SELECT_ARMY:  41.67 - _SELECT_ALL: 1.61
# _MOVE_SCREEN:   45.40 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(37,13)
# Action selected:  [2]
# State value: 7.8312
# Move advantage: 0.3437
# Step 49
# _NO_OP: 	12.55
# _SELECT_ARMY:  42.68 - _SELECT_ALL: 1.47
# _MOVE_SCREEN:   44.77 - _NOT_QUEUED: 0.00 - POINT: (x,y)=(0,0)
# Action selected:  [1]
# State value: 7.9959
# Move advantage: 0.1954

# %% [markdown]
# # Value and policy evolution with training

# %%
load = True
if load:
    agent = torch.load("Results/MoveToBeacon/agent_"+PID, map_location='cpu')
    agent.device = 'cpu'
    agent1 = torch.load("Results/MoveToBeacon/agent_"+PID, map_location='cpu')
    agent1.device = 'cpu'
else: # For models not yet saved because they are still training
    RESOLUTION = 32
    MAX_STEPS = 256
    game_params = dict(feature_screen=RESOLUTION, feature_minimap=RESOLUTION, action_space="FEATURES") 
    env = init_game(game_params, max_steps=MAX_STEPS)
    model_number = 0
    model_names = {0:"FullyConvNet_v0", 1:"FullyConvNet_v1", 2:"FullyConvNet_V2", 3:"ControlNet", 4:"GatedRelationalNet"}

    if model_number == 0:
        print(model_names[model_number]+" selected.")
        spatial_model = net.FullyConvSpatial
        nonspatial_model = net.FullyConvNonSpatial
        n_channels = 32
        n_features = 256
        spatial_dict = {"in_channels":2}
        nonspatial_dict = {'resolution':RESOLUTION}

    elif model_number == 1:
        print(model_names[model_number]+" selected.")
        spatial_model = net.FullyConvSpatial_v1
        nonspatial_model = net.FullyConvNonSpatial_v1
        n_channels = 32
        n_features = 256
        spatial_dict = {"in_channels":3, 'resolution':RESOLUTION}
        nonspatial_dict = {'resolution':RESOLUTION}

    elif model_number == 2:
        print(model_names[model_number]+" selected.")
        spatial_model = net.FullyConvSpatial_v2
        nonspatial_model = net.FullyConvNonSpatial_v2
        n_channels = 32
        n_features = 256
        spatial_dict = {"in_channels":6, 'resolution':RESOLUTION}
        nonspatial_dict = {'resolution':RESOLUTION}

    elif model_number == 3:
        print(model_names[model_number]+" selected.")
        spatial_model = net.SpatialFeatures
        nonspatial_model = net.NonSpatialFeatures
        n_channels = 36
        n_features = 36
        spatial_dict = dict(n_layers=1, linear_size=RESOLUTION, in_channels=6, n_channels=n_features)
        nonspatial_dict = dict(linear_size=RESOLUTION, n_channels=n_features, pixel_hidden_dim=128, pixel_n_residuals=2, 
                     feature_hidden_dim=64, feature_n_residuals=2)
    elif model_number == 4:
        print(model_names[model_number]+" selected.")
        patial_model = net.SpatialFeatures
        nonspatial_model = net.GatedRelationalNet
        n_channels = 32
        n_features = 32
        spatial_dict = dict(n_layers=2, linear_size=RESOLUTION, in_channels=3, n_channels=n_features)

        nonspatial_dict = dict(n_kernels=n_features, n_features=n_features, n_heads=1, n_attn_modules=2, 
                         feature_hidden_dim=16, feature_n_residuals=1)

    else:
        print("Model number not available. Choose 0, 1, 2 or 3.")
        
    HPs = dict(action_space=3, gamma=0.99, n_steps=20, H=1e-3, 
           spatial_model=spatial_model, nonspatial_model=nonspatial_model,
           n_features=n_features, n_channels=n_channels, 
           spatial_dict=spatial_dict, nonspatial_dict=nonspatial_dict)

    # Load on cpu 
    HPs['device'] = 'cpu'

    lr = 7e-4
    agent = SpatialA2C(env=env, **HPs)
    agent1 = SpatialA2C(env=env, **HPs)

# %% [markdown]
# This is showing for each position on the map that can be occupied by the agent how good that postion is, considering where the beacon is located.

# %%
print("PID: ", PID)
init_step = 0
step_jump = 4800
n_jumps = 25
# Out:
# PID:  WUAY

# %%
plot_value_maps(agent, PID, init_step, step_jump, n_jumps, beacon_pos = [4,5], n_channels=2, res=32)

# %%
plot_decision_maps(agent, PID, init_step, step_jump, n_jumps, agent_pos_lst=[[2,2],[5,5],[8,8]], 
                       beacon_pos = [4,5], selected=True, n_channels=2, res=32)

# %% [markdown]
# # Gradient check in decision map

# %%
agent.AC.state_dict().keys()
# Out:
# odict_keys(['spatial_features_net.net.0.weight', 'spatial_features_net.net.0.bias', 'spatial_features_net.net.2.weight', 'spatial_features_net.net.2.bias', 'nonspatial_features_net.conv.0.weight', 'nonspatial_features_net.conv.0.bias', 'nonspatial_features_net.net.0.weight', 'nonspatial_features_net.net.0.bias', 'actor.linear.weight', 'actor.linear.bias', 'critic.net.weight', 'critic.net.bias', 'arguments_networks.queued.net.0.weight', 'arguments_networks.queued.net.0.bias', 'arguments_networks.queued.net.2.weight', 'arguments_networks.queued.net.2.bias', 'arguments_networks.screen.conv.0.weight', 'arguments_networks.screen.conv.0.bias', 'arguments_networks.select_add.net.0.weight', 'arguments_networks.select_add.net.0.bias', 'arguments_networks.select_add.net.2.weight', 'arguments_networks.select_add.net.2.bias'])

# %%
init_step = 0
step_jump = 4800
n_jumps = 25
abs_diff = []
for n in range(1,n_jumps):
    
    step_idx = init_step + step_jump*n
    agent.AC.load_state_dict(torch.load("Results/MoveToBeacon/Checkpoints/"+PID+"_"+str(step_idx), map_location='cpu'))
    agent.AC.to(agent.device) 
    
    step_idx = init_step + step_jump*(n+1)
    agent1.AC.load_state_dict(torch.load("Results/MoveToBeacon/Checkpoints/"+PID+"_"+str(step_idx), map_location='cpu'))
    agent1.AC.to(agent.device) 
    
    named_params = agent.AC.named_parameters()
    named_params1 = agent1.AC.named_parameters()
    layers = []
    mean_abs_diff = []
    for n, p in named_params:
        n1, p1 = next(named_params1)
        if(p.requires_grad) and ("bias" not in n):
            layers.append(n)
            d = p - p1
            d = np.abs(d.detach().numpy()).mean()
            mean_abs_diff.append(d)    
    abs_diff.append(mean_abs_diff)

# %%
fig = plt.figure(figsize=(8,6))
plt.xlabel("Layers", fontsize=16)
plt.ylabel("Average absolute weight diff", fontsize=16)
plt.title("Gradient flow", fontsize=16)
for i in range(len(abs_diff)):
    plt.plot(np.arange(len(abs_diff[i])), abs_diff[i], c='b', alpha=0.5)
plt.xticks(range(0,len(abs_diff[0]), 1), layers, rotation="vertical")
plt.grid(True)
plt.show()

# %% [markdown]
# # Comments
#
# Architecture analysed:
# FullyConv (slightly modified), 32x32
#
# - Spatial network:
#     - conv 5x5, padding 2, 16 kernels
#     - ReLU
#     - conv 3x3, padding 1, 32 kernels
#     - ReLU
# - Non-Spatial network:
#     - conv (3x3, stride 2, padding 0, 64 kernels) used to reduce spatial resolution (`new_res=(old_res-kernel_size)//stride +1)`)
#     - flatten on pixel + channel dimensions (15x15x64 -> 14400) + linear layer (14400 -> 256) with ReLU
#
# We obtain a 256-dimensional vector, used to compute the policy, value and categorical (non-spatial) parameters.
# - Policy net: 256-> n_actions (3)
# - Value net: 256 -> 1
# - Categorical net: 256 -> 256 -> ReLU -> n_values (usually 2, for boolean flags)
#
# To compute the spatial parameters:
# - Conv2d 1x1 kernel from 32 to 1 channels (obtain 1 channel image and sample the pixel after softmax)
#
# **Learning rate**: <br>
# - $7\cdot 10^{-4}$
#
# **n-steps used**:
# - Average from 1 to 32 steps
#
# **Entropy regularization**:
# - $10^{-3}$ for all probabilities (also those from the parameters, not just the main actions)
#
# **Steps done**:
# - 120k (~50 min)
#
# **Unroll length**:
# -  240
#
# **Steps to convergence**:
# - 28k
#
# **Problems - SOLVED**:
# 1. Value map is completely biased, with a baseline of 1 and an asymmetric high-value band on the lower part of the map that is completely wrong
# 2. Decision map is good in shape, but the values are on the wrong scale (too compressed, so that the difference between good and bad samples is shrinked)
# 3. The rendering made by the environment is confusing the agent, because when is near the beacon it disappears, so sometimes it learns to select it again, instead of choosing to click on the beacon
# 4. With the parameters that I chosen the average is ill defined, because I always consider n terms in the average, even if the timestep is less than n steps from the final state; so basically the second to last step is using once the 1-step reward and n-1 times the 2-step reward.
# 5. I'm still wondering how is working the movement, because the agent motion doesn't seem correlated at all with the point selected in the present or previous state.
#
# **Update**:
# 1. Value map it's okay for 2 reasons:
#     - The lower band is never explored and is an artifact of perspective. Maybe more layers would help in understanding that
#     - The value is higher than a single reward because the episode continues even after, so the value is estimating the infinite discounted return that an agent given the current policy and the discount factor would achive.
# 2. Confirmed the compression of values, looks like a lack of expressional power of the architecture
# 3. At the same time it is also true that an episode never starts with the agent superimposed on the beacon, so the agent is in the beacon cells only when is already selected and thus the optimal action if the agent is not visible is always to click at the center of the beacon.
# 4. Still to fix
# 5. Perspective and action queueing are making everything more difficult to understand
#
# **Obs**:
# - double layer in the SpatialParameters network is able to map to 0 all pixels of the map and to non-zero just those that are not visible/accessible.
# - This means that somehow there is no signal flowing backwards from the reward; Strangely it started doing like that from the very beginning...
