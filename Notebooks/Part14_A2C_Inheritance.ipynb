# %% [markdown]
# # A2C derivate classes

# %%
import sys
sys.path.insert(0, "../")
from SC_Utils.game_utils import ObsProcesser, get_action_dict
from SC_Utils.train_v2 import *
from AC_modules.BatchedA2C import SpatialA2C, SpatialA2C_v1, SpatialA2C_v2, SpatialA2C_v3
import AC_modules.Networks as net
import torch
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Environment parameters
RESOLUTION = 32
MAX_STEPS = 256
game_params = dict(feature_screen=RESOLUTION, feature_minimap=RESOLUTION, action_space="FEATURES") 
game_names = {1:'MoveToBeacon',
              2:'CollectMineralShards',
              3:'DefeatRoaches',
              4:'FindAndDefeatZerglings',
              5:'DefeatZerglingsAndBanelings',
              6:'CollectMineralsAndGas',
              7:'BuildMarines'
              }
map_name = game_names[4]

# Observation Processer parameters
#screen_names = ['visibility_map', 'player_relative', 'selected', 'unit_density', 'unit_density_aa']
#minimap_names = []
#obs_proc_params = {'screen_names':screen_names, 'minimap_names':minimap_names}
obs_proc_params = {'select_all':True}

# %%
env = init_game(game_params, map_name)
op = ObsProcesser(**obs_proc_params)
screen_channels, minimap_channels = op.get_n_channels()
in_channels = screen_channels + minimap_channels

# %%
#action_names = ['select_point', 'Move_screen']
#action_names = ['select_army','Move_screen']
action_names = ['select_army', 'Attack_screen', 'Move_screen', 'select_point', 'select_rect',
                'move_camera','Stop_quick','Move_minimap','Attack_minimap','HoldPosition_quick']
action_dict = get_action_dict(action_names)
action_space = len(action_dict)

# %%
spatial_model = net.FullyConvSpatial
nonspatial_model = net.FullyConvNonSpatial
embed_dim = 8
n_channels = 32
n_features = 256
spatial_dict = {"in_channels":in_channels}
nonspatial_dict = {'resolution':RESOLUTION, 'kernel_size':3, 'stride':2}

# %%
HPs = dict(action_space=action_space, gamma=0.99, n_steps=20, H=1e-3, 
           spatial_model=spatial_model, nonspatial_model=nonspatial_model,
           n_features=n_features, n_channels=n_channels, 
           spatial_dict=spatial_dict, nonspatial_dict=nonspatial_dict, 
           action_dict=action_dict)

if torch.cuda.is_available():
    HPs['device'] = 'cuda'
else:
    HPs['device'] = 'cpu'
    
print("Using device "+HPs['device'])

lr = 7e-4
# Out:
# Using device cuda

# %%
version = 2
if version == 1:
    HPs = {**HPs, 'embed_dim':embed_dim}
    agent = SpatialA2C_v1(env=env, **HPs)
elif version == 2:
    # no action embedding
    agent = SpatialA2C_v2(env=env, **HPs)
elif version == 3:
    agent = SpatialA2C_v3(env=env, **HPs)
else:
    raise Exception("Version not implemented.")
# Out:
# arg.name:  select_add
# arg_name:  select_army/select_add
# size:  (2,)
# Init CategoricalNet for select_army/select_add argument
#
# arg.name:  queued
# arg_name:  Attack_screen/queued
# size:  (2,)
# Init CategoricalNet for Attack_screen/queued argument
#
# arg.name:  screen
# arg_name:  Attack_screen/screen
# size:  (32, 32)
# Init SpatialNet for Attack_screen/screen argument
#
# arg.name:  queued
# arg_name:  Move_screen/queued
# size:  (2,)
# Init CategoricalNet for Move_screen/queued argument
#
# arg.name:  screen
# arg_name:  Move_screen/screen
# size:  (32, 32)
# Init SpatialNet for Move_screen/screen argument
#
# arg.name:  select_point_act
# arg_name:  select_point/select_point_act
# size:  (4,)
# Init CategoricalNet for select_point/select_point_act argument
#
# arg.name:  screen
# arg_name:  select_point/screen
# size:  (32, 32)
# Init SpatialNet for select_point/screen argument
#
# arg.name:  select_add
# arg_name:  select_rect/select_add
# size:  (2,)
# Init CategoricalNet for select_rect/select_add argument
#
# arg.name:  screen
# arg_name:  select_rect/screen
# size:  (32, 32)
# Init SpatialNet for select_rect/screen argument
#
# arg.name:  screen2
# arg_name:  select_rect/screen2
# size:  (32, 32)
# Init SpatialNet for select_rect/screen2 argument
#
# arg.name:  minimap
# arg_name:  move_camera/minimap
# size:  (32, 32)
# Init SpatialNet for move_camera/minimap argument
#
# arg.name:  queued
# arg_name:  Stop_quick/queued
# size:  (2,)
# Init CategoricalNet for Stop_quick/queued argument
#
# arg.name:  queued
# arg_name:  Move_minimap/queued
# size:  (2,)
# Init CategoricalNet for Move_minimap/queued argument
#
# arg.name:  minimap
# arg_name:  Move_minimap/minimap
# size:  (32, 32)
# Init SpatialNet for Move_minimap/minimap argument
#
# arg.name:  queued
# arg_name:  Attack_minimap/queued
# size:  (2,)
# Init CategoricalNet for Attack_minimap/queued argument
#
# arg.name:  minimap
# arg_name:  Attack_minimap/minimap
# size:  (32, 32)
# Init SpatialNet for Attack_minimap/minimap argument
#
# arg.name:  queued
# arg_name:  HoldPosition_quick/queued
# size:  (2,)
# Init CategoricalNet for HoldPosition_quick/queued argument

# %%
unroll_length = 60

train_dict = dict(n_train_processes = 11,
                  max_train_steps = unroll_length*20000,
                  unroll_length = unroll_length,
                  test_interval = unroll_length*20 #100
                  )

# %%
# %%time
results = train_batched_A2C(agent, game_params, map_name, lr, 
                            obs_proc_params=obs_proc_params, action_dict=action_dict, **train_dict)
# Out:
# Process ID:  RAVT
# Step # : 1200, avg score : 12.2
# Step # : 2400, avg score : 12.0
# Step # : 3600, avg score : 14.8
# Step # : 4800, avg score : 16.0
# Step # : 6000, avg score : 20.2
# Step # : 7200, avg score : 16.0
# Step # : 8400, avg score : 17.6
# Step # : 9600, avg score : 18.6
# Step # : 10800, avg score : 12.6
# Step # : 12000, avg score : 19.0
# Step # : 13200, avg score : 22.0
# Step # : 14400, avg score : 23.4
# Step # : 15600, avg score : 19.4
# Step # : 16800, avg score : 24.6
# Step # : 18000, avg score : 22.6
# Step # : 19200, avg score : 21.4
# Step # : 20400, avg score : 23.8
# Step # : 21600, avg score : 20.0
# Step # : 22800, avg score : 22.4
# Step # : 24000, avg score : 21.6
# Step # : 25200, avg score : 19.2
# Step # : 26400, avg score : 18.8
# Step # : 27600, avg score : 24.8
# Step # : 28800, avg score : 22.6
# Step # : 30000, avg score : 22.0
# Step # : 31200, avg score : 21.4
# Step # : 32400, avg score : 20.2
# Step # : 33600, avg score : 21.4
# Step # : 34800, avg score : 22.6
# Step # : 36000, avg score : 23.0
# Step # : 37200, avg score : 20.4
# Step # : 38400, avg score : 20.0
# Step # : 39600, avg score : 22.2
# Step # : 40800, avg score : 21.0
# Step # : 42000, avg score : 21.6
# Step # : 43200, avg score : 21.6
# Step # : 44400, avg score : 22.4
# Step # : 45600, avg score : 21.6
# Step # : 46800, avg score : 21.2
# Step # : 48000, avg score : 22.8
# Step # : 49200, avg score : 22.0
# Step # : 50400, avg score : 21.2
# Step # : 51600, avg score : 22.2
# Step # : 52800, avg score : 21.8
# Step # : 54000, avg score : 24.8
# Step # : 55200, avg score : 23.4
# Step # : 56400, avg score : 19.6
# Step # : 57600, avg score : 22.6
# Step # : 58800, avg score : 20.4
# Step # : 60000, avg score : 21.2
# Step # : 61200, avg score : 22.6
# Step # : 62400, avg score : 18.8
# Step # : 63600, avg score : 22.4
# Step # : 64800, avg score : 23.0
# Step # : 66000, avg score : 23.8
# Step # : 67200, avg score : 19.0
# Step # : 68400, avg score : 22.6
# Step # : 69600, avg score : 22.4
# Step # : 70800, avg score : 20.0
# Step # : 72000, avg score : 21.2
# Step # : 73200, avg score : 19.8
# Step # : 74400, avg score : 20.2
# Step # : 75600, avg score : 19.6
# Step # : 76800, avg score : 24.0
# Step # : 78000, avg score : 22.8
# Step # : 79200, avg score : 20.2
# Step # : 80400, avg score : 22.0
# Step # : 81600, avg score : 23.2
# Step # : 82800, avg score : 21.8
# Step # : 84000, avg score : 22.6
# Step # : 85200, avg score : 22.4
# Step # : 86400, avg score : 22.2
# Step # : 87600, avg score : 23.2
# Step # : 88800, avg score : 22.0
# Step # : 90000, avg score : 21.4
# Step # : 91200, avg score : 23.0
# Step # : 92400, avg score : 24.4
# Step # : 93600, avg score : 21.6
# Step # : 94800, avg score : 23.4
# Step # : 96000, avg score : 21.2
# Step # : 97200, avg score : 25.4
# Step # : 98400, avg score : 20.6
# Step # : 99600, avg score : 24.2
# Step # : 100800, avg score : 24.8
# Step # : 102000, avg score : 20.8
# Step # : 103200, avg score : 20.4
# Step # : 104400, avg score : 22.2
# Step # : 105600, avg score : 22.6
# Step # : 106800, avg score : 22.2
# Step # : 108000, avg score : 21.0
# Step # : 109200, avg score : 22.4
# Step # : 110400, avg score : 23.2
# Step # : 111600, avg score : 22.6
# Step # : 112800, avg score : 22.6
# Step # : 114000, avg score : 21.4
# Step # : 115200, avg score : 22.4
# Step # : 116400, avg score : 22.4
# Step # : 117600, avg score : 22.4
# Step # : 118800, avg score : 19.8
# Step # : 120000, avg score : 22.0
# Step # : 121200, avg score : 20.6
# Step # : 122400, avg score : 23.6
# Step # : 123600, avg score : 21.8
# Step # : 124800, avg score : 21.6
# Step # : 126000, avg score : 22.0
# Step # : 127200, avg score : 22.4
# Step # : 128400, avg score : 20.4
# Step # : 129600, avg score : 22.2
# Step # : 130800, avg score : 19.6
# Step # : 132000, avg score : 20.0
# Step # : 133200, avg score : 22.8
# Step # : 134400, avg score : 21.8
# Step # : 135600, avg score : 21.8
# Step # : 136800, avg score : 24.6
# Step # : 138000, avg score : 22.4
# Step # : 139200, avg score : 23.4
# Step # : 140400, avg score : 22.6
# Step # : 141600, avg score : 23.8
# Step # : 142800, avg score : 23.0
# Step # : 144000, avg score : 23.0
# Step # : 145200, avg score : 20.6
# Step # : 146400, avg score : 21.8
# Step # : 147600, avg score : 21.0
# Step # : 148800, avg score : 22.6
# Step # : 150000, avg score : 21.2
# Step # : 151200, avg score : 22.6
# Step # : 152400, avg score : 22.4
# Step # : 153600, avg score : 22.2
# Step # : 154800, avg score : 22.2
# Step # : 156000, avg score : 19.4
# Step # : 157200, avg score : 21.4
# Step # : 158400, avg score : 21.8
# Step # : 159600, avg score : 22.8
# Step # : 160800, avg score : 21.0
# Step # : 162000, avg score : 23.2
# Step # : 163200, avg score : 21.8
# Step # : 164400, avg score : 22.2
# Step # : 165600, avg score : 25.0
# Step # : 166800, avg score : 24.2
# Step # : 168000, avg score : 20.6
# Step # : 169200, avg score : 16.4
# Step # : 170400, avg score : 22.4
# Step # : 171600, avg score : 19.6
# Step # : 172800, avg score : 20.0
# Step # : 174000, avg score : 22.0
# Step # : 175200, avg score : 23.2
# Step # : 176400, avg score : 23.0
# Step # : 177600, avg score : 24.0
# Step # : 178800, avg score : 21.2
# Step # : 180000, avg score : 22.0
# Step # : 181200, avg score : 19.8
# Step # : 182400, avg score : 21.2
# Step # : 183600, avg score : 24.2
# Step # : 184800, avg score : 22.0
# Step # : 186000, avg score : 19.4
# Step # : 187200, avg score : 20.4
# Step # : 188400, avg score : 21.8
# Step # : 189600, avg score : 20.6
# Step # : 190800, avg score : 20.6
# Step # : 192000, avg score : 22.2
# Step # : 193200, avg score : 20.4
# Step # : 194400, avg score : 23.4
# Step # : 195600, avg score : 23.0
# Step # : 196800, avg score : 20.8
# Step # : 198000, avg score : 21.8
# Step # : 199200, avg score : 24.4
# Step # : 200400, avg score : 22.2
# Step # : 201600, avg score : 23.2
# Step # : 202800, avg score : 23.2
# Step # : 204000, avg score : 19.8
# Step # : 205200, avg score : 20.2
# Step # : 206400, avg score : 21.8
# Step # : 207600, avg score : 22.8
# Step # : 208800, avg score : 17.4
# Step # : 210000, avg score : 23.4
# Step # : 211200, avg score : 18.2
# Step # : 212400, avg score : 23.2
# Step # : 213600, avg score : 21.4
# Step # : 214800, avg score : 17.6
# Step # : 216000, avg score : 20.2
# Step # : 217200, avg score : 21.6
# Step # : 218400, avg score : 21.4
# Step # : 219600, avg score : 24.4
# Step # : 220800, avg score : 22.0
# Step # : 222000, avg score : 21.2
# Step # : 223200, avg score : 21.0
# Step # : 224400, avg score : 23.0
# Step # : 225600, avg score : 23.0
# Step # : 226800, avg score : 20.4
# Step # : 228000, avg score : 23.4
# Step # : 229200, avg score : 21.4
# Step # : 230400, avg score : 20.6
# Step # : 231600, avg score : 23.0
# Step # : 232800, avg score : 23.0
# Step # : 234000, avg score : 25.6
# Step # : 235200, avg score : 22.6
# Step # : 236400, avg score : 21.6
# Step # : 237600, avg score : 22.6
# Step # : 238800, avg score : 24.4
# Step # : 240000, avg score : 22.4
# Step # : 241200, avg score : 21.4
# Step # : 242400, avg score : 21.6
# Step # : 243600, avg score : 21.2
# Step # : 244800, avg score : 17.8
# Step # : 246000, avg score : 20.8
# Step # : 247200, avg score : 21.8
# Step # : 248400, avg score : 22.8
# Step # : 249600, avg score : 21.6
# Step # : 250800, avg score : 20.0
# Step # : 252000, avg score : 21.2
# Step # : 253200, avg score : 22.0
# Step # : 254400, avg score : 19.0
# Step # : 255600, avg score : 24.2
# Step # : 256800, avg score : 22.2
# Step # : 258000, avg score : 22.4
# Step # : 259200, avg score : 23.4
# Step # : 260400, avg score : 22.6
# Step # : 261600, avg score : 20.4
# Step # : 262800, avg score : 27.8
# Step # : 264000, avg score : 21.8
# Step # : 265200, avg score : 22.4
# Step # : 266400, avg score : 21.2
# Step # : 267600, avg score : 23.6
# Step # : 268800, avg score : 19.6
# Step # : 270000, avg score : 22.6
# Step # : 271200, avg score : 23.6
# Step # : 272400, avg score : 21.2
# Step # : 273600, avg score : 22.6
# Step # : 274800, avg score : 23.0
# Step # : 276000, avg score : 23.8
# Step # : 277200, avg score : 24.2
# Step # : 278400, avg score : 23.6
# Step # : 279600, avg score : 23.8
# Step # : 280800, avg score : 20.0
# Step # : 282000, avg score : 23.6
# Step # : 283200, avg score : 19.4
# Step # : 284400, avg score : 16.8
# Step # : 285600, avg score : 21.0
# Step # : 286800, avg score : 20.8
# Step # : 288000, avg score : 23.6
# Step # : 289200, avg score : 17.6
# Step # : 290400, avg score : 23.8
# Step # : 291600, avg score : 20.2
# Step # : 292800, avg score : 22.4
# Step # : 294000, avg score : 23.2
# Step # : 295200, avg score : 22.4
# Step # : 296400, avg score : 22.0
# Step # : 297600, avg score : 21.2
# Step # : 298800, avg score : 21.6
# Step # : 300000, avg score : 23.0
# Step # : 301200, avg score : 22.8
# Step # : 302400, avg score : 21.0
# Step # : 303600, avg score : 21.6
# Step # : 304800, avg score : 22.2
# Step # : 306000, avg score : 21.4
# Step # : 307200, avg score : 21.4
# Step # : 308400, avg score : 22.4
# Step # : 309600, avg score : 21.2
# Step # : 310800, avg score : 24.6
# Step # : 312000, avg score : 21.6
# Step # : 313200, avg score : 21.8
# Step # : 314400, avg score : 21.6
# Step # : 315600, avg score : 20.2
# Step # : 316800, avg score : 23.0
# Step # : 318000, avg score : 20.4
# Step # : 319200, avg score : 22.8
# Step # : 320400, avg score : 21.4
# Step # : 321600, avg score : 22.0
# Step # : 322800, avg score : 22.2
# Step # : 324000, avg score : 21.2
# Step # : 325200, avg score : 22.8
# Step # : 326400, avg score : 19.6
# Step # : 327600, avg score : 23.8
# Step # : 328800, avg score : 21.8
# Step # : 330000, avg score : 22.4
# Step # : 331200, avg score : 21.2
# Step # : 332400, avg score : 18.4
# Step # : 333600, avg score : 22.8
# Step # : 334800, avg score : 21.2
# Step # : 336000, avg score : 22.2
# Step # : 337200, avg score : 21.0
# Step # : 338400, avg score : 23.0
# Step # : 339600, avg score : 23.0
# Step # : 340800, avg score : 19.8
# Step # : 342000, avg score : 21.0
# Step # : 343200, avg score : 21.6
# Step # : 344400, avg score : 20.8
# Step # : 345600, avg score : 23.0
# Step # : 346800, avg score : 23.2
# Step # : 348000, avg score : 20.4
# Step # : 349200, avg score : 23.0
# Step # : 350400, avg score : 23.2
# Step # : 351600, avg score : 21.2
# Step # : 352800, avg score : 23.2
# Step # : 354000, avg score : 24.8
# Step # : 355200, avg score : 21.8
# Step # : 356400, avg score : 21.8
# Step # : 357600, avg score : 23.4
# Step # : 358800, avg score : 25.2
# Step # : 360000, avg score : 24.2
# Step # : 361200, avg score : 23.2
# Step # : 362400, avg score : 24.4
# Step # : 363600, avg score : 22.2
# Step # : 364800, avg score : 20.2
# Step # : 366000, avg score : 23.6
# Step # : 367200, avg score : 26.0
# Step # : 368400, avg score : 21.0
# Step # : 369600, avg score : 20.6
# Step # : 370800, avg score : 23.0
# Step # : 372000, avg score : 21.8
# Step # : 373200, avg score : 21.0
# Step # : 374400, avg score : 22.4
# Step # : 375600, avg score : 24.8
# Step # : 376800, avg score : 21.8
# Step # : 378000, avg score : 22.0
# Step # : 379200, avg score : 22.6
# Step # : 380400, avg score : 21.8
# Step # : 381600, avg score : 24.0
# Step # : 382800, avg score : 22.6
# Step # : 384000, avg score : 20.8
# Step # : 385200, avg score : 23.0
# Step # : 386400, avg score : 23.4
# Step # : 387600, avg score : 22.4
# Step # : 388800, avg score : 22.0
# Step # : 390000, avg score : 23.6
# Step # : 391200, avg score : 21.0
# Step # : 392400, avg score : 21.2
# Step # : 393600, avg score : 21.2
# Step # : 394800, avg score : 20.6
# Step # : 396000, avg score : 22.8
# Step # : 397200, avg score : 22.2
# Step # : 398400, avg score : 24.4
# Step # : 399600, avg score : 21.8
# Step # : 400800, avg score : 20.8
# Step # : 402000, avg score : 23.6
# Step # : 403200, avg score : 19.4
# Step # : 404400, avg score : 20.0
# Step # : 405600, avg score : 22.4
# Step # : 406800, avg score : 22.4
# Step # : 408000, avg score : 19.2
# Step # : 409200, avg score : 20.4
# Step # : 410400, avg score : 22.2
# Step # : 411600, avg score : 21.8
# Step # : 412800, avg score : 21.8
# Step # : 414000, avg score : 22.0
# Step # : 415200, avg score : 20.6
# Step # : 416400, avg score : 21.6
# Step # : 417600, avg score : 20.0
# Step # : 418800, avg score : 23.0
# Step # : 420000, avg score : 21.6
# Step # : 421200, avg score : 22.6
# Step # : 422400, avg score : 20.8
# Step # : 423600, avg score : 21.0
# Step # : 424800, avg score : 22.4
# Step # : 426000, avg score : 19.2
# Step # : 427200, avg score : 23.4
# Step # : 428400, avg score : 22.4
# Step # : 429600, avg score : 21.4
# Step # : 430800, avg score : 21.4
# Step # : 432000, avg score : 24.4
# Step # : 433200, avg score : 21.6
# Step # : 434400, avg score : 22.4
# Step # : 435600, avg score : 24.0
# Step # : 436800, avg score : 18.6
# Step # : 438000, avg score : 21.0
# Step # : 439200, avg score : 21.6
# Step # : 440400, avg score : 22.0
# Step # : 441600, avg score : 21.8
# Step # : 442800, avg score : 21.8
# Step # : 444000, avg score : 21.2
# Step # : 445200, avg score : 24.4
# Step # : 446400, avg score : 20.4
# Step # : 447600, avg score : 19.0
# Step # : 448800, avg score : 22.6
# Step # : 450000, avg score : 19.8
# Step # : 451200, avg score : 22.6
# Step # : 452400, avg score : 23.8
# Step # : 453600, avg score : 25.0
# Step # : 454800, avg score : 20.8
# Step # : 456000, avg score : 22.2
# Step # : 457200, avg score : 23.2
# Step # : 458400, avg score : 20.6
# Step # : 459600, avg score : 21.4
# Step # : 460800, avg score : 21.0
# Step # : 462000, avg score : 20.2
# Step # : 463200, avg score : 21.6
# Step # : 464400, avg score : 22.8
# Step # : 465600, avg score : 22.4
# Step # : 466800, avg score : 21.0
# Step # : 468000, avg score : 21.4
# Step # : 469200, avg score : 22.2
# Step # : 470400, avg score : 24.2
# Step # : 471600, avg score : 22.2
# Step # : 472800, avg score : 21.6
# Step # : 474000, avg score : 21.0
# Step # : 475200, avg score : 22.2
# Step # : 476400, avg score : 22.8
# Step # : 477600, avg score : 22.6
# Step # : 478800, avg score : 21.6
# Step # : 480000, avg score : 20.8
# Step # : 481200, avg score : 21.8
# Step # : 482400, avg score : 21.8
# Step # : 483600, avg score : 24.0
# Step # : 484800, avg score : 21.8
# Step # : 486000, avg score : 23.0
# Step # : 487200, avg score : 24.4
# Step # : 488400, avg score : 21.6
# Step # : 489600, avg score : 22.0
# Step # : 490800, avg score : 23.2
# Step # : 492000, avg score : 20.6
# Step # : 493200, avg score : 21.8
# Step # : 494400, avg score : 21.8
# Step # : 495600, avg score : 22.6
# Step # : 496800, avg score : 23.6
# Step # : 498000, avg score : 19.4
# Step # : 499200, avg score : 21.8
# Step # : 500400, avg score : 22.2
# Step # : 501600, avg score : 19.6
# Step # : 502800, avg score : 23.4
# Step # : 504000, avg score : 21.8
# Step # : 505200, avg score : 22.8
# Step # : 506400, avg score : 23.6
# Step # : 507600, avg score : 21.4
# Step # : 508800, avg score : 19.6
# Step # : 510000, avg score : 22.4
# Step # : 511200, avg score : 22.8
# Step # : 512400, avg score : 23.0
# Step # : 513600, avg score : 21.8
# Step # : 514800, avg score : 23.0
# Step # : 516000, avg score : 24.4
# Step # : 517200, avg score : 22.0
# Step # : 518400, avg score : 21.4
# Step # : 519600, avg score : 20.6
# Step # : 520800, avg score : 21.4
# Step # : 522000, avg score : 24.2
# Step # : 523200, avg score : 22.2
# Step # : 524400, avg score : 22.4
# Step # : 525600, avg score : 22.0
# Step # : 526800, avg score : 19.8
# Step # : 528000, avg score : 22.0
# Step # : 529200, avg score : 24.2
# Step # : 530400, avg score : 25.6
# Step # : 531600, avg score : 22.4
# Step # : 532800, avg score : 21.2
# Step # : 534000, avg score : 23.6
# Step # : 535200, avg score : 20.2
# Step # : 536400, avg score : 20.4
# Step # : 537600, avg score : 20.0
# Step # : 538800, avg score : 22.0
# Step # : 540000, avg score : 22.6
# Step # : 541200, avg score : 22.0
# Step # : 542400, avg score : 24.0
# Step # : 543600, avg score : 23.6
# Step # : 544800, avg score : 18.4
# Step # : 546000, avg score : 20.0
# Step # : 547200, avg score : 20.8
# Step # : 548400, avg score : 20.8
# Step # : 549600, avg score : 25.6
# Step # : 550800, avg score : 24.6
# Step # : 552000, avg score : 21.2
# Step # : 553200, avg score : 21.6
# Step # : 554400, avg score : 25.0
# Step # : 555600, avg score : 23.0
# Step # : 556800, avg score : 24.2
# Step # : 558000, avg score : 20.2
# Step # : 559200, avg score : 22.2
# Step # : 560400, avg score : 20.4
# Step # : 561600, avg score : 20.8
# Step # : 562800, avg score : 19.2
# Step # : 564000, avg score : 23.8
# Step # : 565200, avg score : 21.4
# Step # : 566400, avg score : 21.2
# Step # : 567600, avg score : 20.4
# Step # : 568800, avg score : 22.0
# Step # : 570000, avg score : 20.4
# Step # : 571200, avg score : 23.6
# Step # : 572400, avg score : 22.4
# Step # : 573600, avg score : 21.8
# Step # : 574800, avg score : 20.4
# Step # : 576000, avg score : 23.2
# Step # : 577200, avg score : 24.2
# Step # : 578400, avg score : 24.2
# Step # : 579600, avg score : 20.4
# Step # : 580800, avg score : 22.4
# Step # : 582000, avg score : 19.6
# Step # : 583200, avg score : 22.6
# Step # : 584400, avg score : 21.2
# Step # : 585600, avg score : 22.2
# Step # : 586800, avg score : 20.8
# Step # : 588000, avg score : 22.8
# Step # : 589200, avg score : 22.2
# Step # : 590400, avg score : 22.8
# Step # : 591600, avg score : 22.8
# Step # : 592800, avg score : 20.6
# Step # : 594000, avg score : 18.8
# Step # : 595200, avg score : 20.4
# Step # : 596400, avg score : 21.6
# Step # : 597600, avg score : 22.2
# Step # : 598800, avg score : 23.8
# Step # : 600000, avg score : 21.8
# Step # : 601200, avg score : 24.4
# Step # : 602400, avg score : 22.0
# Step # : 603600, avg score : 25.6
# Step # : 604800, avg score : 23.2
# Step # : 606000, avg score : 24.0
# Step # : 607200, avg score : 23.4
# Step # : 608400, avg score : 21.8
# Step # : 609600, avg score : 26.0
# Step # : 610800, avg score : 22.4
# Step # : 612000, avg score : 22.0
# Step # : 613200, avg score : 21.4
# Step # : 614400, avg score : 22.0
# Step # : 615600, avg score : 22.4
# Step # : 616800, avg score : 22.0
# Step # : 618000, avg score : 23.0
# Step # : 619200, avg score : 25.8
# Step # : 620400, avg score : 22.2
# Step # : 621600, avg score : 22.0
# Step # : 622800, avg score : 23.6
# Step # : 624000, avg score : 20.4
# Step # : 625200, avg score : 23.6
# Step # : 626400, avg score : 20.6
# Step # : 627600, avg score : 19.2
# Step # : 628800, avg score : 22.0
# Step # : 630000, avg score : 21.8
# Step # : 631200, avg score : 23.4
# Step # : 632400, avg score : 23.4
# Step # : 633600, avg score : 22.6
# Step # : 634800, avg score : 22.0
# Step # : 636000, avg score : 22.2
# Step # : 637200, avg score : 22.8
# Step # : 638400, avg score : 18.6
# Step # : 639600, avg score : 21.6
# Step # : 640800, avg score : 21.0
# Step # : 642000, avg score : 21.4
# Step # : 643200, avg score : 24.0
# Step # : 644400, avg score : 21.0
# Step # : 645600, avg score : 22.6
# Step # : 646800, avg score : 22.0
# Step # : 648000, avg score : 22.2
# Step # : 649200, avg score : 22.2
# Step # : 650400, avg score : 22.4
# Step # : 651600, avg score : 23.2
# Step # : 652800, avg score : 23.2
# Step # : 654000, avg score : 22.4
# Step # : 655200, avg score : 19.2
# Step # : 656400, avg score : 20.6
# Step # : 657600, avg score : 21.6
# Step # : 658800, avg score : 21.8
# Step # : 660000, avg score : 23.2
# Step # : 661200, avg score : 20.6
# Step # : 662400, avg score : 23.6
# Step # : 663600, avg score : 20.6
# Step # : 664800, avg score : 22.0
# Step # : 666000, avg score : 22.2
# Step # : 667200, avg score : 23.0
# Step # : 668400, avg score : 23.2
# Step # : 669600, avg score : 22.8
# Step # : 670800, avg score : 22.2
# Step # : 672000, avg score : 22.8
# Step # : 673200, avg score : 22.4
# Step # : 674400, avg score : 21.4
# Step # : 675600, avg score : 20.4
# Step # : 676800, avg score : 20.2
# Step # : 678000, avg score : 22.4
# Step # : 679200, avg score : 21.4
# Step # : 680400, avg score : 23.8
# Step # : 681600, avg score : 23.4
# Step # : 682800, avg score : 20.2
# Step # : 684000, avg score : 21.2
# Step # : 685200, avg score : 19.2
# Step # : 686400, avg score : 22.0
# Step # : 687600, avg score : 23.2
# Step # : 688800, avg score : 20.4
# Step # : 690000, avg score : 19.4
# Step # : 691200, avg score : 20.6
# Step # : 692400, avg score : 20.2
# Step # : 693600, avg score : 22.6
# Step # : 694800, avg score : 26.4
# Step # : 696000, avg score : 24.2

# %%
# %%time
results = train_batched_A2C(trained_agent, game_params, map_name, lr, 
                            obs_proc_params=obs_proc_params, action_dict=action_dict, **train_dict)
# Out:
# Process ID:  VVLG
# Step # : 6000, avg score : 99.8
# Step # : 12000, avg score : 94.0
# Step # : 18000, avg score : 81.4
# Step # : 24000, avg score : 99.6
# Step # : 30000, avg score : 99.4
# Step # : 36000, avg score : 95.0
# Step # : 42000, avg score : 99.0
# Step # : 48000, avg score : 95.2
# Step # : 54000, avg score : 94.0
# Step # : 60000, avg score : 96.0
# Step # : 66000, avg score : 95.8
# Step # : 72000, avg score : 98.2
# Step # : 78000, avg score : 93.8
# Step # : 84000, avg score : 101.6
# Step # : 90000, avg score : 93.2
# Step # : 96000, avg score : 98.0
# Step # : 102000, avg score : 93.6
# Step # : 108000, avg score : 100.6
# Step # : 114000, avg score : 96.0
# Step # : 120000, avg score : 82.6
# Step # : 126000, avg score : 89.6
# Step # : 132000, avg score : 97.8
# Step # : 138000, avg score : 101.6
# Step # : 144000, avg score : 99.2
# Step # : 150000, avg score : 97.8
# Step # : 156000, avg score : 92.0
# Step # : 162000, avg score : 96.2
# Step # : 168000, avg score : 91.6
# Step # : 174000, avg score : 99.0
# Step # : 180000, avg score : 97.0
# Step # : 186000, avg score : 103.0
# Step # : 192000, avg score : 92.8
# Step # : 198000, avg score : 93.2
# Step # : 204000, avg score : 103.8
# Step # : 210000, avg score : 96.2
# Step # : 216000, avg score : 97.8
# Step # : 222000, avg score : 94.8
# Step # : 228000, avg score : 100.6
# Step # : 234000, avg score : 82.8
# Step # : 240000, avg score : 100.4
# Step # : 246000, avg score : 103.4
# Step # : 252000, avg score : 100.6
# Step # : 258000, avg score : 101.0
# Step # : 264000, avg score : 92.8
# Step # : 270000, avg score : 101.8
# Step # : 276000, avg score : 94.2
# Step # : 282000, avg score : 94.6
# Step # : 288000, avg score : 95.0
# Step # : 294000, avg score : 94.2
# Step # : 300000, avg score : 95.4
# Step # : 306000, avg score : 93.8
# Step # : 312000, avg score : 102.2
# Step # : 318000, avg score : 95.8
# Step # : 324000, avg score : 100.0
# Step # : 330000, avg score : 100.6
# Step # : 336000, avg score : 97.8
# Step # : 342000, avg score : 101.6
# Step # : 348000, avg score : 98.6
# Step # : 354000, avg score : 102.0
# Step # : 360000, avg score : 103.4
# Step # : 366000, avg score : 94.8
# Step # : 372000, avg score : 97.4
# Step # : 378000, avg score : 97.8
# Step # : 384000, avg score : 95.2
# Step # : 390000, avg score : 94.6
# Step # : 396000, avg score : 92.8
# Step # : 402000, avg score : 100.2
# Step # : 408000, avg score : 101.0
# Step # : 414000, avg score : 97.0
# Step # : 420000, avg score : 96.4
# Step # : 426000, avg score : 97.4
# Step # : 432000, avg score : 99.2
# Step # : 438000, avg score : 97.4
# Step # : 444000, avg score : 106.0
# Step # : 450000, avg score : 88.2
# Step # : 456000, avg score : 97.4
# Step # : 462000, avg score : 95.2
# Step # : 468000, avg score : 96.6
# Step # : 474000, avg score : 99.0
# Step # : 480000, avg score : 93.2
# Step # : 486000, avg score : 92.2
# Step # : 492000, avg score : 99.2
# Step # : 498000, avg score : 100.0
# Step # : 504000, avg score : 85.0
# Step # : 510000, avg score : 89.6
# Step # : 516000, avg score : 98.0
# Step # : 522000, avg score : 92.6
# Step # : 528000, avg score : 96.6
# Step # : 534000, avg score : 96.0
# Step # : 540000, avg score : 97.8
# Step # : 546000, avg score : 98.6
# Step # : 552000, avg score : 90.8
# Step # : 558000, avg score : 102.0
# Step # : 564000, avg score : 98.6
# Step # : 570000, avg score : 93.0
# Step # : 576000, avg score : 95.6
# Step # : 582000, avg score : 96.2
# Step # : 588000, avg score : 97.8
# Step # : 594000, avg score : 99.6
# Step # : 600000, avg score : 95.6
# Step # : 606000, avg score : 89.8
# Step # : 612000, avg score : 91.2
# Step # : 618000, avg score : 83.4
# Step # : 624000, avg score : 95.6
# Step # : 630000, avg score : 94.0
# Step # : 636000, avg score : 96.2
# Step # : 642000, avg score : 97.8
# Step # : 648000, avg score : 96.2
# Step # : 654000, avg score : 96.2
# Step # : 660000, avg score : 95.4
# Step # : 666000, avg score : 105.8
# Step # : 672000, avg score : 94.4
# Step # : 678000, avg score : 100.4
# Step # : 684000, avg score : 102.6
# Step # : 690000, avg score : 96.6
# Step # : 696000, avg score : 97.2
# Step # : 702000, avg score : 96.8
# Step # : 708000, avg score : 91.2
# Step # : 714000, avg score : 102.0
# Step # : 720000, avg score : 96.6
# Step # : 726000, avg score : 100.0
# Step # : 732000, avg score : 96.0
# Step # : 738000, avg score : 98.2
# Step # : 744000, avg score : 96.0
# Step # : 750000, avg score : 99.4
# Step # : 756000, avg score : 96.4
# Step # : 762000, avg score : 98.2
# Step # : 768000, avg score : 102.2
# Step # : 774000, avg score : 98.8
# Step # : 780000, avg score : 99.6
# Step # : 786000, avg score : 101.4
# Step # : 792000, avg score : 95.2
# Step # : 798000, avg score : 94.4
# Step # : 804000, avg score : 96.0
# Step # : 810000, avg score : 90.4
# Step # : 816000, avg score : 95.0
# Step # : 822000, avg score : 100.2
# Step # : 828000, avg score : 102.2
# Step # : 834000, avg score : 100.2
# Step # : 840000, avg score : 103.6
# Step # : 846000, avg score : 101.8
# Step # : 852000, avg score : 98.4
# Step # : 858000, avg score : 96.4
# Step # : 864000, avg score : 94.6
# Step # : 870000, avg score : 93.8
# Step # : 876000, avg score : 97.4
# Step # : 882000, avg score : 103.2
# Step # : 888000, avg score : 84.8
# Step # : 894000, avg score : 96.2
# Step # : 900000, avg score : 94.2
# Step # : 906000, avg score : 98.6
# Step # : 912000, avg score : 98.2
# Step # : 918000, avg score : 99.4
# Step # : 924000, avg score : 98.8
# Step # : 930000, avg score : 98.0
# Step # : 936000, avg score : 92.4
# Step # : 942000, avg score : 94.0
# Step # : 948000, avg score : 102.2
# Step # : 954000, avg score : 97.0
# Step # : 960000, avg score : 91.8
# Step # : 966000, avg score : 97.6
# Step # : 972000, avg score : 93.0
# Step # : 978000, avg score : 99.0
# Step # : 984000, avg score : 95.8
# Step # : 990000, avg score : 95.2
# Step # : 996000, avg score : 100.0
# Step # : 1002000, avg score : 96.2
# Step # : 1008000, avg score : 101.0
# Step # : 1014000, avg score : 94.0
# Step # : 1020000, avg score : 102.4
# Step # : 1026000, avg score : 95.6
# Step # : 1032000, avg score : 72.0
# Step # : 1038000, avg score : 45.2
# Step # : 1044000, avg score : 85.4
# Step # : 1050000, avg score : 76.2
# Step # : 1056000, avg score : 88.4
# Step # : 1062000, avg score : 92.4
# Step # : 1068000, avg score : 97.0
# Step # : 1074000, avg score : 94.6
# Step # : 1080000, avg score : 97.2
# Step # : 1086000, avg score : 91.0
# Step # : 1092000, avg score : 92.4
# Step # : 1098000, avg score : 93.0
# Step # : 1104000, avg score : 96.6
# Step # : 1110000, avg score : 90.8
# Step # : 1116000, avg score : 92.6
# Step # : 1122000, avg score : 97.4
# Step # : 1128000, avg score : 92.2
# Step # : 1134000, avg score : 94.2
# Step # : 1140000, avg score : 90.6
# Step # : 1146000, avg score : 91.6
# Step # : 1152000, avg score : 96.2
# Step # : 1158000, avg score : 99.2
# Step # : 1164000, avg score : 97.4
# Step # : 1170000, avg score : 87.8
# Step # : 1176000, avg score : 94.0
# Step # : 1182000, avg score : 95.2
# Step # : 1188000, avg score : 90.0
# Step # : 1194000, avg score : 100.8
# Step # : 1200000, avg score : 98.2
# CPU times: user 1d 14h 31min 6s, sys: 1h 12min 21s, total: 1d 15h 43min 27s
# Wall time: 8h 53min 17s

# %%
score, losses, trained_agent, PID = results

# %%
from Utils import utils
save = True
keywords = ['A2C', 'CMS','embed-action',"conv-net",'lr-7e-4','20-steps', '32x32',"1.2M-env-steps","120-unroll-len",'7-channels', 'select-point'] 

if save:
    save_dir = '../Results/CollectMineralShards/'
    keywords.append(PID)
    filename = '_'.join(keywords)
    filename = 'S_'+filename
    print("Save at "+save_dir+filename)
    train_session_dict = dict(game_params=game_params, HPs=HPs, score=score, n_epochs=len(score), keywords=keywords, losses=losses)
    np.save(save_dir+filename, train_session_dict)
    torch.save(trained_agent, save_dir+"agent_"+PID)
else:
    print("Nothing saved")
    pass
# Out:
# Save at ../Results/CollectMineralShards/S_A2C_CMS_embed-action_conv-net_lr-7e-4_20-steps_32x32_1.2M-env-steps_120-unroll-len_7-channels_select-point_VYPP
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type SpatialActorCritic_v1. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type FullyConvSpatial. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Sequential. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Conv2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ReLU. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type FullyConvNonSpatial. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Linear. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type SharedActor. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type SharedCritic. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ModuleDict. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type CategoricalNet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type SpatialParameters. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Embedding. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %% [markdown]
# # FiLM layer for action conditioning
#
# How I condition actions right now:
# - action = (b,)
# - embedded_a = (b,d), d is embedding dimension (e.g. 8)
# - for nonspatial features (b, n_features) just concatenate the embedded action: (b, n_features+d)
# - for spatial features (b, n_channels, L, L) broadcast (actually repeat) the embedded action to (b,d,L,L) and then concatenate along the channel dimension: (b, n_channels+d, L, L)
#
# Then I use them as always, so processing from 1 or 2 layers before applying the softmax and sampling the argument.
#
# With FiLM for spatial arguments:
# - still use embedding
# - use ReLU + linear layer to extract $\gamma_c$ and $\beta_c$ for each channel c in n_channels
# - transform the spatial features as $\gamma_c F_c(x) + \beta_c$
# - apply final convolution layer
# - apply softmax
#
# Same thing can be done for nonspatial arguments, assuming them as 1x1 images. So in this case the FiLM layer would be much more expressive, because it can achieve any possible output by means of scaling and shifting, so maybe is no more a good idea and a simple concatenation of the embedding action could do.

# %% [markdown]
# # Tests

# %%
class C1():
    def __init__(self):
        self._init_stuff()
        self.C = 10
        
    def _init_stuff(self):
        self.N = 10

# %%
class C2(C1):
    def __init__(self):
        self.embed = 10
        super().__init__()
        print(self.N)
        print(self.C)
        
    def _init_stuff(self):
        self.N = 10 + self.embed

# %%
C2()
# Out:
# 20
# 10

# %%
B = 2
n_channels = 12
n_features = 256
embed_dim = 16
res = 32
spatial = torch.rand(B, n_channels, res, res)
nonspatial = torch.rand(B, n_features)
embedded_a = torch.rand(B, embed_dim)

# %%
print('embedded_a.shape; ', embedded_a.shape)
spatial_a = embedded_a.reshape((embedded_a.shape[:2]+(1,1,))).repeat(1,1,res,res)
for i in range(res):
    for j in range(res):
        print(torch.all(spatial_a[:,:,i,j] == embedded_a)) # copied correctly if True
# Out:
# embedded_a.shape;  torch.Size([2, 16])
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)

# %%
cat_spatial = torch.cat([spatial, spatial_a], dim=1)

# %%
cat_spatial.shape
# Out:
# torch.Size([2, 28, 32, 32])

# %%
cat_nonspatial = torch.cat([nonspatial, embedded_a], dim=1)
cat_nonspatial.shape
# Out:
# torch.Size([2, 272])
