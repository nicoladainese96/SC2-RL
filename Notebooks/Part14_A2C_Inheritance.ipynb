# %% [markdown]
# # A2C derivate classes

# %%
import sys
sys.path.insert(0, "../")
from SC_Utils.game_utils import ObsProcesser, get_action_dict
from SC_Utils.train_v2 import *
from AC_modules.BatchedA2C import SpatialA2C, SpatialA2C_v1, SpatialA2C_v2, SpatialA2C_v3, SpatialA2C_MaxEnt
import AC_modules.Networks as net
import torch
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Environment parameters
RESOLUTION = 32
game_params = dict(feature_screen=RESOLUTION, feature_minimap=RESOLUTION, action_space="FEATURES") 
game_names = {1:'MoveToBeacon',
              2:'CollectMineralShards',
              3:'DefeatRoaches',
              4:'FindAndDefeatZerglings',
              5:'DefeatZerglingsAndBanelings',
              6:'CollectMineralsAndGas',
              7:'BuildMarines'
              }
map_name = game_names[1]

# Observation Processer parameters
#screen_names = ['visibility_map', 'player_relative', 'selected', 'unit_density', 'unit_density_aa']
#minimap_names = []
#obs_proc_params = {'screen_names':screen_names, 'minimap_names':minimap_names}
obs_proc_params = {'select_all':True}

# %%
env = init_game(game_params, map_name)
op = ObsProcesser(**obs_proc_params)
screen_channels, minimap_channels = op.get_n_channels()
in_channels = screen_channels + minimap_channels

# %%
action_names = ['select_point', 'Move_screen','Attack_screen']
#action_names = ['select_army','Move_screen']
#action_names = ['select_army', 'Attack_screen', 'Move_screen', 'select_point', 'select_rect',
#                'move_camera','Stop_quick','Move_minimap','Attack_minimap','HoldPosition_quick']
action_dict = get_action_dict(action_names)
action_space = len(action_dict)

# %%
spatial_model = net.FullyConvSpatial
nonspatial_model = net.FullyConvNonSpatial
embed_dim = 8
n_channels = 32
n_features = 256
spatial_dict = {"in_channels":in_channels}
nonspatial_dict = {'resolution':RESOLUTION, 'kernel_size':3, 'stride':2}

# %%
HPs = dict(action_space=action_space, gamma=0.99, n_steps=20, H=1e-3, 
           spatial_model=spatial_model, nonspatial_model=nonspatial_model,
           n_features=n_features, n_channels=n_channels, 
           spatial_dict=spatial_dict, nonspatial_dict=nonspatial_dict, 
           action_dict=action_dict)

if torch.cuda.is_available():
    HPs['device'] = 'cuda'
else:
    HPs['device'] = 'cpu'
    
print("Using device "+HPs['device'])

lr = 7e-4
# Out:
# Using device cpu

# %%
version = 4
if version == 1:
    HPs = {**HPs, 'embed_dim':embed_dim}
    agent = SpatialA2C_v1(env=env, **HPs)
elif version == 2:
    # no action embedding
    agent = SpatialA2C_v2(env=env, **HPs)
elif version == 3:
    agent = SpatialA2C_v3(env=env, **HPs)
elif version == 4:
    # no action embedding
    agent = SpatialA2C_MaxEnt(env=env, **HPs)
else:
    raise Exception("Version not implemented.")

# %%
unroll_length = 60

train_dict = dict(n_train_processes = 5,
                  max_train_steps = unroll_length*60000,
                  unroll_length = unroll_length,
                  test_interval = unroll_length*10
                  )

# %%
# %%time
results = train_batched_A2C(agent, game_params, map_name, lr, 
                            obs_proc_params=obs_proc_params, action_dict=action_dict, **train_dict)
# Out:
# Process ID:  ARXS
# Process Process-5:
# Process Process-2:
# Process Process-3:
# Process Process-1:
# Process Process-4:
# Traceback (most recent call last):
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "../SC_Utils/train_v2.py", line 72, in worker
#     cmd, data = worker_end.recv()
#   File "../SC_Utils/train_v2.py", line 72, in worker
#     cmd, data = worker_end.recv()
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# Traceback (most recent call last):
#   File "../SC_Utils/train_v2.py", line 72, in worker
#     cmd, data = worker_end.recv()
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "../SC_Utils/train_v2.py", line 72, in worker
#     cmd, data = worker_end.recv()
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "../SC_Utils/train_v2.py", line 72, in worker
#     cmd, data = worker_end.recv()
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
# KeyboardInterrupt
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/pysc2/lib/protocol.py", line 66, in catch_websocket_connection_errors
#     yield
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/pysc2/lib/protocol.py", line 183, in _read
#     response_str = self._sock.recv()
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/websocket/_core.py", line 314, in recv
#     opcode, data = self.recv_data()
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/websocket/_core.py", line 331, in recv_data
#     opcode, frame = self.recv_data_frame(control_frame)
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/websocket/_core.py", line 344, in recv_data_frame
#     frame = self.recv_frame()
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/websocket/_core.py", line 378, in recv_frame
#     return self.frame_buffer.recv_frame()
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/websocket/_abnf.py", line 361, in recv_frame
#     self.recv_header()
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/websocket/_abnf.py", line 309, in recv_header
#     header = self.recv_strict(2)
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/websocket/_abnf.py", line 396, in recv_strict
#     bytes_ = self.recv(min(16384, shortage))
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/websocket/_core.py", line 453, in _recv
#     return recv(self.sock, bufsize)
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/websocket/_socket.py", line 102, in recv
#     bytes_ = _recv()
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/websocket/_socket.py", line 84, in _recv
#     return sock.recv(bufsize)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/pysc2/lib/protocol.py", line 151, in send
#     res = self.send_req(req)
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/pysc2/lib/protocol.py", line 131, in send_req
#     return self.read()
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/pysc2/lib/stopwatch.py", line 212, in _stopwatch
#     return func(*args, **kwargs)
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/pysc2/lib/protocol.py", line 102, in read
#     response = self._read()
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/pysc2/lib/protocol.py", line 183, in _read
#     response_str = self._sock.recv()
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/contextlib.py", line 130, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/pysc2/lib/protocol.py", line 73, in catch_websocket_connection_errors
#     raise ConnectionError("Socket error: %s" % e)
# pysc2.lib.protocol.ConnectionError: Socket error: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/IPython/core/magics/execution.py", line 1312, in time
#     exec(code, glob, local_ns)
#   File "<timed exec>", line 2, in <module>
#   File "../SC_Utils/train_v2.py", line 239, in train_batched_A2C
#     avg_score = test(step_idx, agent, test_env, PID, op, action_dict, num_tests, save_path)
#   File "../SC_Utils/train_v2.py", line 269, in test
#     obs = test_env.step(a)
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/pysc2/lib/stopwatch.py", line 212, in _stopwatch
#     return func(*args, **kwargs)
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/pysc2/env/sc2_env.py", line 545, in step
#     for c, a in zip(self._controllers, actions))
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/pysc2/lib/run_parallel.py", line 56, in run
#     return [funcs[0]()]
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/pysc2/lib/remote_controller.py", line 85, in _skip_status
#     return func(self, *args, **kwargs)
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/pysc2/lib/remote_controller.py", line 99, in _valid_status
#     return func(self, *args, **kwargs)
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/pysc2/lib/remote_controller.py", line 111, in _catch_game_end
#     return func(self, *args, **kwargs)
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/pysc2/lib/stopwatch.py", line 212, in _stopwatch
#     return func(*args, **kwargs)
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/pysc2/lib/remote_controller.py", line 301, in actions
#     return self._client.send(action=req_action)
#   File "/u/94/dainesn1/unix/.local/lib/python3.7/site-packages/pysc2/lib/protocol.py", line 153, in send
#     raise ConnectionError("Error during %s: %s" % (name, e))
# pysc2.lib.protocol.ConnectionError: Error during action: Socket error: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ConnectionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1151, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "/m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/pysc2/lib/protocol.py in catch_websocket_connection_errors()
#      65   try:
# ---> 66     yield
#      67   except websocket.WebSocketConnectionClosedException:
#
# ~/.local/lib/python3.7/site-packages/pysc2/lib/protocol.py in _read(self)
#     182       with catch_websocket_connection_errors():
# --> 183         response_str = self._sock.recv()
#     184     if not response_str:
#
# ~/.local/lib/python3.7/site-packages/websocket/_core.py in recv(self)
#     313         with self.readlock:
# --> 314             opcode, data = self.recv_data()
#     315         if six.PY3 and opcode == ABNF.OPCODE_TEXT:
#
# ~/.local/lib/python3.7/site-packages/websocket/_core.py in recv_data(self, control_frame)
#     330         """
# --> 331         opcode, frame = self.recv_data_frame(control_frame)
#     332         return opcode, frame.data
#
# ~/.local/lib/python3.7/site-packages/websocket/_core.py in recv_data_frame(self, control_frame)
#     343         while True:
# --> 344             frame = self.recv_frame()
#     345             if not frame:
#
# ~/.local/lib/python3.7/site-packages/websocket/_core.py in recv_frame(self)
#     377         """
# --> 378         return self.frame_buffer.recv_frame()
#     379
#
# ~/.local/lib/python3.7/site-packages/websocket/_abnf.py in recv_frame(self)
#     360             if self.has_received_header():
# --> 361                 self.recv_header()
#     362             (fin, rsv1, rsv2, rsv3, opcode, has_mask, _) = self.header
#
# ~/.local/lib/python3.7/site-packages/websocket/_abnf.py in recv_header(self)
#     308     def recv_header(self):
# --> 309         header = self.recv_strict(2)
#     310         b1 = header[0]
#
# ~/.local/lib/python3.7/site-packages/websocket/_abnf.py in recv_strict(self, bufsize)
#     395             # fragmentation.
# --> 396             bytes_ = self.recv(min(16384, shortage))
#     397             self.recv_buffer.append(bytes_)
#
# ~/.local/lib/python3.7/site-packages/websocket/_core.py in _recv(self, bufsize)
#     452         try:
# --> 453             return recv(self.sock, bufsize)
#     454         except WebSocketConnectionClosedException:
#
# ~/.local/lib/python3.7/site-packages/websocket/_socket.py in recv(sock, bufsize)
#     101         else:
# --> 102             bytes_ = _recv()
#     103     except socket.timeout as e:
#
# ~/.local/lib/python3.7/site-packages/websocket/_socket.py in _recv()
#      83         try:
# ---> 84             return sock.recv(bufsize)
#      85         except SSLWantReadError:
#
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/pysc2/lib/protocol.py in send(self, **kwargs)
#     150     try:
# --> 151       res = self.send_req(req)
#     152     except ConnectionError as e:
#
# ~/.local/lib/python3.7/site-packages/pysc2/lib/protocol.py in send_req(self, request)
#     130     self.write(request)
# --> 131     return self.read()
#     132
#
# ~/.local/lib/python3.7/site-packages/pysc2/lib/stopwatch.py in _stopwatch(*args, **kwargs)
#     211         with self(name):
# --> 212           return func(*args, **kwargs)
#     213       return _stopwatch
#
# ~/.local/lib/python3.7/site-packages/pysc2/lib/protocol.py in read(self)
#     101       start = time.time()
# --> 102     response = self._read()
#     103     if FLAGS.sc2_verbose_protocol:
#
# ~/.local/lib/python3.7/site-packages/pysc2/lib/protocol.py in _read(self)
#     182       with catch_websocket_connection_errors():
# --> 183         response_str = self._sock.recv()
#     184     if not response_str:
#
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#
# ~/.local/lib/python3.7/site-packages/pysc2/lib/protocol.py in catch_websocket_connection_errors()
#      72   except socket.error as e:
# ---> 73     raise ConnectionError("Socket error: %s" % e)
#      74
#
# ConnectionError: Socket error: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1311             try:
# -> 1312                 exec(code, glob, local_ns)
#    1313                 out=None
#
# <timed exec> in <module>
#
# /m/home/home9/94/dainesn1/unix/Workdir/SC2-RL/SC_Utils/train_v2.py in train_batched_A2C(agent, game_params, map_name, lr, n_train_processes, max_train_steps, unroll_length, obs_proc_params, action_dict, test_interval, num_tests, inspection_interval, save_path)
#     238                     print("#Steps,score", file=f)
# --> 239             avg_score = test(step_idx, agent, test_env, PID, op, action_dict, num_tests, save_path)
#     240             if inspection and (step_idx%inspection_interval==0):
#
# /m/home/home9/94/dainesn1/unix/Workdir/SC2-RL/SC_Utils/train_v2.py in test(step_idx, agent, test_env, process_ID, op, action_dict, num_test, save_path)
#     268             a, log_prob, probs = agent.step(s, a_mask)
# --> 269             obs = test_env.step(a)
#     270             s_prime_dict, _ = op.get_state(obs)
#
# ~/.local/lib/python3.7/site-packages/pysc2/lib/stopwatch.py in _stopwatch(*args, **kwargs)
#     211         with self(name):
# --> 212           return func(*args, **kwargs)
#     213       return _stopwatch
#
# ~/.local/lib/python3.7/site-packages/pysc2/env/sc2_env.py in step(self, actions, step_mul)
#     544     self._parallel.run((c.actions, sc_pb.RequestAction(actions=a))
# --> 545                        for c, a in zip(self._controllers, actions))
#     546
#
# ~/.local/lib/python3.7/site-packages/pysc2/lib/run_parallel.py in run(self, funcs)
#      55     if len(funcs) == 1:  # Ignore threads if it's not needed.
# ---> 56       return [funcs[0]()]
#      57     if len(funcs) > self._workers:  # Lazy init and grow as needed.
#
# ~/.local/lib/python3.7/site-packages/pysc2/lib/remote_controller.py in _skip_status(self, *args, **kwargs)
#      84       if self.status not in skipped:
# ---> 85         return func(self, *args, **kwargs)
#      86     return _skip_status
#
# ~/.local/lib/python3.7/site-packages/pysc2/lib/remote_controller.py in _valid_status(self, *args, **kwargs)
#      98                 func.__name__, self.status, ",".join(map(str, valid))))
# ---> 99       return func(self, *args, **kwargs)
#     100     return _valid_status
#
# ~/.local/lib/python3.7/site-packages/pysc2/lib/remote_controller.py in _catch_game_end(self, *args, **kwargs)
#     110     try:
# --> 111       return func(self, *args, **kwargs)
#     112     except protocol.ProtocolError as protocol_error:
#
# ~/.local/lib/python3.7/site-packages/pysc2/lib/stopwatch.py in _stopwatch(*args, **kwargs)
#     211         with self(name):
# --> 212           return func(*args, **kwargs)
#     213       return _stopwatch
#
# ~/.local/lib/python3.7/site-packages/pysc2/lib/remote_controller.py in actions(self, req_action)
#     300
# --> 301     return self._client.send(action=req_action)
#     302
#
# ~/.local/lib/python3.7/site-packages/pysc2/lib/protocol.py in send(self, **kwargs)
#     152     except ConnectionError as e:
# --> 153       raise ConnectionError("Error during %s: %s" % (name, e))
#     154     if res.HasField("id") and res.id != req.id:
#
# ConnectionError: Error during action: Socket error: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'ConnectionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-6ca13a5311d7> in <module>
# ----> 1 get_ipython().run_cell_magic('time', '', 'results = train_batched_A2C(agent, game_params, map_name, lr, \n                            obs_proc_params=obs_proc_params, action_dict=action_dict, **train_dict)\n')
#
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2360             with self.builtin_trap:
#    2361                 args = (magic_arg_s, cell)
# -> 2362                 result = fn(*args, **kwargs)
#    2363             return result
#    2364
#
# </m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/decorator.py:decorator-gen-61> in time(self, line, cell, local_ns)
#
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1317                     out = eval(code_2, glob, local_ns)
#    1318             except:
# -> 1319                 self.shell.showtraceback()
#    1320                 return
#    1321             end = clock2()
#
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2045                     except Exception:
#    2046                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2047                                             value, tb, tb_offset=tb_offset)
#    2048
#    2049                     self._showtraceback(etype, value, stb)
#
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1416             self.tb = tb
#    1417         return FormattedTB.structured_traceback(
# -> 1418             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1419
#    1420
#
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1316             # Verbose modes need a full traceback
#    1317             return VerboseTB.structured_traceback(
# -> 1318                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1319             )
#    1320         elif mode == 'Minimal':
#
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1184         exception = self.get_parts_of_chained_exception(evalue)
#    1185         if exception:
# -> 1186             formatted_exceptions += self.prepare_chained_exception_message(evalue.__cause__)
#    1187             etype, evalue, etb = exception
#    1188         else:
#
# TypeError: can only concatenate str (not "list") to str

# %%
# %%time
results = train_batched_A2C(trained_agent, game_params, map_name, lr, 
                            obs_proc_params=obs_proc_params, action_dict=action_dict, **train_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# NameError: name 'trained_agent' is not defined

# %%
score, losses, trained_agent, PID = results

# %%
from Utils import utils
save = True
keywords = ['A2C', 'CMS','embed-action',"conv-net",'lr-7e-4','20-steps', '32x32',"1.2M-env-steps","120-unroll-len",'7-channels', 'select-point'] 

if save:
    save_dir = '../Results/CollectMineralShards/'
    keywords.append(PID)
    filename = '_'.join(keywords)
    filename = 'S_'+filename
    print("Save at "+save_dir+filename)
    train_session_dict = dict(game_params=game_params, HPs=HPs, score=score, n_epochs=len(score), keywords=keywords, losses=losses)
    np.save(save_dir+filename, train_session_dict)
    torch.save(trained_agent, save_dir+"agent_"+PID)
else:
    print("Nothing saved")
    pass
# Out:
# Save at ../Results/CollectMineralShards/S_A2C_CMS_embed-action_conv-net_lr-7e-4_20-steps_32x32_1.2M-env-steps_120-unroll-len_7-channels_select-point_VYPP
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type SpatialActorCritic_v1. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type FullyConvSpatial. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Sequential. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Conv2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ReLU. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type FullyConvNonSpatial. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Linear. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type SharedActor. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type SharedCritic. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ModuleDict. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type CategoricalNet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type SpatialParameters. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /m/work/modules/automatic/anaconda/envs/aalto-ubuntu1804-generic/software/anaconda/2020-01-tf2/5a34a04a/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Embedding. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %% [markdown]
# # FiLM layer for action conditioning
#
# How I condition actions right now:
# - action = (b,)
# - embedded_a = (b,d), d is embedding dimension (e.g. 8)
# - for nonspatial features (b, n_features) just concatenate the embedded action: (b, n_features+d)
# - for spatial features (b, n_channels, L, L) broadcast (actually repeat) the embedded action to (b,d,L,L) and then concatenate along the channel dimension: (b, n_channels+d, L, L)
#
# Then I use them as always, so processing from 1 or 2 layers before applying the softmax and sampling the argument.
#
# With FiLM for spatial arguments:
# - still use embedding
# - use ReLU + linear layer to extract $\gamma_c$ and $\beta_c$ for each channel c in n_channels
# - transform the spatial features as $\gamma_c F_c(x) + \beta_c$
# - apply final convolution layer
# - apply softmax
#
# Same thing can be done for nonspatial arguments, assuming them as 1x1 images. So in this case the FiLM layer would be much more expressive, because it can achieve any possible output by means of scaling and shifting, so maybe is no more a good idea and a simple concatenation of the embedding action could do.

# %% [markdown]
# # Tests

# %%
class C1():
    def __init__(self):
        self._init_stuff()
        self.C = 10
        
    def _init_stuff(self):
        self.N = 10

# %%
class C2(C1):
    def __init__(self):
        self.embed = 10
        super().__init__()
        print(self.N)
        print(self.C)
        
    def _init_stuff(self):
        self.N = 10 + self.embed

# %%
C2()
# Out:
# 20
# 10

# %%
B = 2
n_channels = 12
n_features = 256
embed_dim = 16
res = 32
spatial = torch.rand(B, n_channels, res, res)
nonspatial = torch.rand(B, n_features)
embedded_a = torch.rand(B, embed_dim)

# %%
print('embedded_a.shape; ', embedded_a.shape)
spatial_a = embedded_a.reshape((embedded_a.shape[:2]+(1,1,))).repeat(1,1,res,res)
for i in range(res):
    for j in range(res):
        print(torch.all(spatial_a[:,:,i,j] == embedded_a)) # copied correctly if True
# Out:
# embedded_a.shape;  torch.Size([2, 16])
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)
# tensor(True)

# %%
cat_spatial = torch.cat([spatial, spatial_a], dim=1)

# %%
cat_spatial.shape
# Out:
# torch.Size([2, 28, 32, 32])

# %%
cat_nonspatial = torch.cat([nonspatial, embedded_a], dim=1)
cat_nonspatial.shape
# Out:
# torch.Size([2, 272])
