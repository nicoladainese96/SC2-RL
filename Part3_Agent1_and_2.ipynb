# %% [markdown]
# # StarCraft II - Testing agents

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from RelationalModule import CoordActorCritic, OheActorCritic
from Utils import train, plot, utils
from importlib import reload
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
reload(CoordActorCritic)
reload(train)
reload(plot)
reload(utils)
# Out:
# <module 'Utils.utils' from '/home/nicola/Nicola_unipd/MasterThesis/SC2-RL/Utils/utils.py'>

# %% [markdown]
# # Agent 1

# %%
HPs = dict(action_space=3, observation_space=6, lr=0.0005, gamma=0.9, TD=True, 
                 twin=True, tau=0.1, n_steps=40, H=1e-3, hiddens=[64,32,16])
    
agent = CoordActorCritic.MoveToBeaconA2C(**HPs)

# %%
replay_dict = dict(save_replay_episodes=1000,
                   replay_dir='Replays/',
                   replay_prefix='Agent1')

game_params = dict(feature_screen=16, # screen resolution in pixel
                      feature_minimap=16, # minimap resolution in pixel (smaller or equal to screen)
                      action_space="FEATURES") # either FEATURES or RGB - suggested: FEATURES

MAX_STEPS = 256
N_EPISODES = 3000

# %%
# Init environment + play one episode + update agent

env = train.init_game(game_params, max_steps=MAX_STEPS, **replay_dict)

results = train.play_episode(agent, env, MAX_STEPS)
rewards, log_probs, distributions, states, done, bootstrap = results

losses = agent.update(rewards, log_probs, distributions, states, done, bootstrap)
critic_loss, agent_loss, negative_entropy_term = losses

print("rewards: ", rewards.shape)
print("log_probs: ", len(log_probs))
print("distributions: ", len(distributions))
print("states: ", states.shape)
print("done: ", done.shape)
print("bootstrap: ", bootstrap.shape)
# Out:
# rewards:  (240,)
# log_probs:  240
# distributions:  240
# states:  (241, 6)
# done:  (240,)
# bootstrap:  (240,)

# %% [markdown]
# ## Training cycle

# %%
# %%time
results = train.train_SC2_agent(agent, game_params, N_EPISODES, MAX_STEPS, return_agent=True,  **replay_dict)
# Out:
# Episode 10 - reward: 18.80
# 	Time playing the episode: 2.52 s
# 	Time updating the agent: 0.14 s
# Episode 20 - reward: 18.80
# 	Time playing the episode: 2.53 s
# 	Time updating the agent: 0.15 s
# Episode 30 - reward: 20.90
# 	Time playing the episode: 2.48 s
# 	Time updating the agent: 0.13 s
# Episode 40 - reward: 22.40
# 	Time playing the episode: 2.55 s
# 	Time updating the agent: 0.14 s
# Episode 50 - reward: 21.40
# 	Time playing the episode: 2.72 s
# 	Time updating the agent: 0.13 s
# Episode 60 - reward: 21.30
# 	Time playing the episode: 2.53 s
# 	Time updating the agent: 0.14 s
# Episode 70 - reward: 22.30
# 	Time playing the episode: 2.48 s
# 	Time updating the agent: 0.14 s
# Episode 80 - reward: 22.70
# 	Time playing the episode: 2.55 s
# 	Time updating the agent: 0.14 s
# Episode 90 - reward: 23.70
# 	Time playing the episode: 2.55 s
# 	Time updating the agent: 0.13 s
# Episode 100 - reward: 24.40
# 	Time playing the episode: 2.52 s
# 	Time updating the agent: 0.13 s
# Episode 110 - reward: 23.60
# 	Time playing the episode: 2.58 s
# 	Time updating the agent: 0.15 s
# Episode 120 - reward: 23.40
# 	Time playing the episode: 2.57 s
# 	Time updating the agent: 0.13 s
# Episode 130 - reward: 24.30
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.13 s
# Episode 140 - reward: 25.20
# 	Time playing the episode: 2.58 s
# 	Time updating the agent: 0.14 s
# Episode 150 - reward: 23.80
# 	Time playing the episode: 2.65 s
# 	Time updating the agent: 0.13 s
# Episode 160 - reward: 24.20
# 	Time playing the episode: 2.66 s
# 	Time updating the agent: 0.13 s
# Episode 170 - reward: 24.00
# 	Time playing the episode: 2.68 s
# 	Time updating the agent: 0.13 s
# Episode 180 - reward: 24.70
# 	Time playing the episode: 2.64 s
# 	Time updating the agent: 0.16 s
# Episode 190 - reward: 24.70
# 	Time playing the episode: 2.65 s
# 	Time updating the agent: 0.14 s
# Episode 200 - reward: 24.80
# 	Time playing the episode: 2.72 s
# 	Time updating the agent: 0.14 s
# Episode 210 - reward: 25.40
# 	Time playing the episode: 2.71 s
# 	Time updating the agent: 0.14 s
# Episode 220 - reward: 26.30
# 	Time playing the episode: 2.64 s
# 	Time updating the agent: 0.13 s
# Episode 230 - reward: 24.70
# 	Time playing the episode: 2.58 s
# 	Time updating the agent: 0.15 s
# Episode 240 - reward: 24.90
# 	Time playing the episode: 2.67 s
# 	Time updating the agent: 0.13 s
# Episode 250 - reward: 24.60
# 	Time playing the episode: 2.59 s
# 	Time updating the agent: 0.13 s
# Episode 260 - reward: 25.40
# 	Time playing the episode: 2.68 s
# 	Time updating the agent: 0.13 s
# Episode 270 - reward: 25.10
# 	Time playing the episode: 2.71 s
# 	Time updating the agent: 0.13 s
# Episode 280 - reward: 25.60
# 	Time playing the episode: 2.58 s
# 	Time updating the agent: 0.13 s
# Episode 290 - reward: 25.60
# 	Time playing the episode: 2.65 s
# 	Time updating the agent: 0.13 s
# Episode 300 - reward: 24.90
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.13 s
# Episode 310 - reward: 24.80
# 	Time playing the episode: 2.71 s
# 	Time updating the agent: 0.14 s
# Episode 320 - reward: 25.10
# 	Time playing the episode: 2.77 s
# 	Time updating the agent: 0.15 s
# Episode 330 - reward: 24.60
# 	Time playing the episode: 2.68 s
# 	Time updating the agent: 0.15 s
# Episode 340 - reward: 24.20
# 	Time playing the episode: 2.70 s
# 	Time updating the agent: 0.14 s
# Episode 350 - reward: 25.70
# 	Time playing the episode: 2.79 s
# 	Time updating the agent: 0.13 s
# Episode 360 - reward: 24.70
# 	Time playing the episode: 2.60 s
# 	Time updating the agent: 0.14 s
# Episode 370 - reward: 25.00
# 	Time playing the episode: 2.65 s
# 	Time updating the agent: 0.13 s
# Episode 380 - reward: 25.60
# 	Time playing the episode: 2.67 s
# 	Time updating the agent: 0.14 s
# Episode 390 - reward: 24.70
# 	Time playing the episode: 2.66 s
# 	Time updating the agent: 0.15 s
# Episode 400 - reward: 25.50
# 	Time playing the episode: 2.68 s
# 	Time updating the agent: 0.13 s
# Episode 410 - reward: 25.10
# 	Time playing the episode: 2.63 s
# 	Time updating the agent: 0.13 s
# Episode 420 - reward: 25.20
# 	Time playing the episode: 2.75 s
# 	Time updating the agent: 0.39 s
# Episode 430 - reward: 25.40
# 	Time playing the episode: 2.68 s
# 	Time updating the agent: 0.14 s
# Episode 440 - reward: 26.00
# 	Time playing the episode: 2.83 s
# 	Time updating the agent: 0.14 s
# Episode 450 - reward: 26.30
# 	Time playing the episode: 2.65 s
# 	Time updating the agent: 0.13 s
# Episode 460 - reward: 24.70
# 	Time playing the episode: 2.64 s
# 	Time updating the agent: 0.14 s
# Episode 470 - reward: 26.00
# 	Time playing the episode: 2.78 s
# 	Time updating the agent: 0.13 s
# Episode 480 - reward: 24.30
# 	Time playing the episode: 2.66 s
# 	Time updating the agent: 0.14 s
# Episode 490 - reward: 25.80
# 	Time playing the episode: 2.63 s
# 	Time updating the agent: 0.13 s
# Episode 500 - reward: 25.60
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.14 s
# Episode 510 - reward: 25.70
# 	Time playing the episode: 2.66 s
# 	Time updating the agent: 0.13 s
# Episode 520 - reward: 24.20
# 	Time playing the episode: 2.40 s
# 	Time updating the agent: 0.14 s
# Episode 530 - reward: 25.70
# 	Time playing the episode: 2.70 s
# 	Time updating the agent: 0.13 s
# Episode 540 - reward: 26.10
# 	Time playing the episode: 2.68 s
# 	Time updating the agent: 0.15 s
# Episode 550 - reward: 25.30
# 	Time playing the episode: 2.62 s
# 	Time updating the agent: 0.15 s
# Episode 560 - reward: 25.40
# 	Time playing the episode: 2.80 s
# 	Time updating the agent: 0.14 s
# Episode 570 - reward: 26.00
# 	Time playing the episode: 2.64 s
# 	Time updating the agent: 0.15 s
# Episode 580 - reward: 24.90
# 	Time playing the episode: 2.67 s
# 	Time updating the agent: 0.15 s
# Episode 590 - reward: 25.60
# 	Time playing the episode: 2.68 s
# 	Time updating the agent: 0.13 s
# Episode 600 - reward: 24.90
# 	Time playing the episode: 2.65 s
# 	Time updating the agent: 0.13 s
# Episode 610 - reward: 25.80
# 	Time playing the episode: 2.63 s
# 	Time updating the agent: 0.13 s
# Episode 620 - reward: 24.80
# 	Time playing the episode: 2.64 s
# 	Time updating the agent: 0.13 s
# Episode 630 - reward: 25.60
# 	Time playing the episode: 2.62 s
# 	Time updating the agent: 0.13 s
# Episode 640 - reward: 26.50
# 	Time playing the episode: 2.60 s
# 	Time updating the agent: 0.13 s
# Episode 650 - reward: 25.10
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.13 s
# Episode 660 - reward: 25.30
# 	Time playing the episode: 2.62 s
# 	Time updating the agent: 0.13 s
# Episode 670 - reward: 25.30
# 	Time playing the episode: 2.60 s
# 	Time updating the agent: 0.13 s
# Episode 680 - reward: 26.00
# 	Time playing the episode: 2.62 s
# 	Time updating the agent: 0.13 s
# Episode 690 - reward: 25.60
# 	Time playing the episode: 2.64 s
# 	Time updating the agent: 0.13 s
# Episode 700 - reward: 25.60
# 	Time playing the episode: 2.62 s
# 	Time updating the agent: 0.13 s
# Episode 710 - reward: 24.90
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.13 s
# Episode 720 - reward: 25.20
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.13 s
# Episode 730 - reward: 27.30
# 	Time playing the episode: 2.60 s
# 	Time updating the agent: 0.13 s
# Episode 740 - reward: 25.20
# 	Time playing the episode: 2.65 s
# 	Time updating the agent: 0.14 s
# Episode 750 - reward: 25.10
# 	Time playing the episode: 2.62 s
# 	Time updating the agent: 0.14 s
# Episode 760 - reward: 25.40
# 	Time playing the episode: 2.60 s
# 	Time updating the agent: 0.13 s
# Episode 770 - reward: 25.90
# 	Time playing the episode: 2.59 s
# 	Time updating the agent: 0.13 s
# Episode 780 - reward: 25.80
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.13 s
# Episode 790 - reward: 25.10
# 	Time playing the episode: 2.64 s
# 	Time updating the agent: 0.15 s
# Episode 800 - reward: 25.90
# 	Time playing the episode: 2.76 s
# 	Time updating the agent: 0.14 s
# Episode 810 - reward: 25.30
# 	Time playing the episode: 2.94 s
# 	Time updating the agent: 0.18 s
# Episode 820 - reward: 26.20
# 	Time playing the episode: 2.69 s
# 	Time updating the agent: 0.13 s
# Episode 830 - reward: 25.80
# 	Time playing the episode: 2.79 s
# 	Time updating the agent: 0.13 s
# Episode 840 - reward: 26.80
# 	Time playing the episode: 2.73 s
# 	Time updating the agent: 0.14 s
# Episode 850 - reward: 25.90
# 	Time playing the episode: 2.69 s
# 	Time updating the agent: 0.13 s
# Episode 860 - reward: 25.90
# 	Time playing the episode: 2.69 s
# 	Time updating the agent: 0.14 s
# Episode 870 - reward: 25.30
# 	Time playing the episode: 2.77 s
# 	Time updating the agent: 0.13 s
# Episode 880 - reward: 25.40
# 	Time playing the episode: 2.69 s
# 	Time updating the agent: 0.13 s
# Episode 890 - reward: 26.20
# 	Time playing the episode: 2.79 s
# 	Time updating the agent: 0.13 s
# Episode 900 - reward: 25.60
# 	Time playing the episode: 2.77 s
# 	Time updating the agent: 0.15 s
# Episode 910 - reward: 26.00
# 	Time playing the episode: 2.67 s
# 	Time updating the agent: 0.13 s
# Episode 920 - reward: 26.90
# 	Time playing the episode: 2.68 s
# 	Time updating the agent: 0.14 s
# Episode 930 - reward: 25.60
# 	Time playing the episode: 2.67 s
# 	Time updating the agent: 0.13 s
# Episode 940 - reward: 25.50
# 	Time playing the episode: 2.80 s
# 	Time updating the agent: 0.18 s
# Episode 950 - reward: 25.90
# 	Time playing the episode: 2.81 s
# 	Time updating the agent: 0.13 s
# Episode 960 - reward: 25.90
# 	Time playing the episode: 6.00 s
# 	Time updating the agent: 0.15 s
# Episode 970 - reward: 26.40
# 	Time playing the episode: 2.71 s
# 	Time updating the agent: 0.14 s
# Episode 980 - reward: 24.60
# 	Time playing the episode: 2.69 s
# 	Time updating the agent: 0.13 s
# Episode 990 - reward: 25.40
# 	Time playing the episode: 2.63 s
# 	Time updating the agent: 0.14 s
# Episode 1000 - reward: 25.10
# 	Time playing the episode: 2.69 s
# 	Time updating the agent: 0.14 s
# Episode 1010 - reward: 25.40
# 	Time playing the episode: 2.64 s
# 	Time updating the agent: 0.14 s
# Episode 1020 - reward: 26.60
# 	Time playing the episode: 2.65 s
# 	Time updating the agent: 0.13 s
# Episode 1030 - reward: 25.00
# 	Time playing the episode: 2.67 s
# 	Time updating the agent: 0.14 s
# Episode 1040 - reward: 26.10
# 	Time playing the episode: 2.69 s
# 	Time updating the agent: 0.15 s
# Episode 1050 - reward: 26.60
# 	Time playing the episode: 2.63 s
# 	Time updating the agent: 0.13 s
# Episode 1060 - reward: 27.20
# 	Time playing the episode: 2.65 s
# 	Time updating the agent: 0.13 s
# Episode 1070 - reward: 25.80
# 	Time playing the episode: 2.66 s
# 	Time updating the agent: 0.14 s
# Episode 1080 - reward: 25.80
# 	Time playing the episode: 2.69 s
# 	Time updating the agent: 0.13 s
# Episode 1090 - reward: 24.90
# 	Time playing the episode: 2.66 s
# 	Time updating the agent: 0.14 s
# Episode 1100 - reward: 25.10
# 	Time playing the episode: 2.71 s
# 	Time updating the agent: 0.15 s
# Episode 1110 - reward: 25.80
# 	Time playing the episode: 2.72 s
# 	Time updating the agent: 0.14 s
# Episode 1120 - reward: 26.20
# 	Time playing the episode: 2.67 s
# 	Time updating the agent: 0.13 s
# Episode 1130 - reward: 25.50
# 	Time playing the episode: 2.65 s
# 	Time updating the agent: 0.15 s
# Episode 1140 - reward: 25.90
# 	Time playing the episode: 2.64 s
# 	Time updating the agent: 0.17 s
# Episode 1150 - reward: 26.50
# 	Time playing the episode: 2.84 s
# 	Time updating the agent: 0.15 s
# Episode 1160 - reward: 25.70
# 	Time playing the episode: 2.72 s
# 	Time updating the agent: 0.13 s
# Episode 1170 - reward: 26.10
# 	Time playing the episode: 2.75 s
# 	Time updating the agent: 0.14 s
# Episode 1180 - reward: 26.20
# 	Time playing the episode: 2.69 s
# 	Time updating the agent: 0.15 s
# Episode 1190 - reward: 26.70
# 	Time playing the episode: 2.75 s
# 	Time updating the agent: 0.15 s
# Episode 1200 - reward: 25.50
# 	Time playing the episode: 2.72 s
# 	Time updating the agent: 0.13 s
# Episode 1210 - reward: 25.60
# 	Time playing the episode: 2.69 s
# 	Time updating the agent: 0.13 s
# Episode 1220 - reward: 26.00
# 	Time playing the episode: 2.77 s
# 	Time updating the agent: 0.15 s
# Episode 1230 - reward: 25.60
# 	Time playing the episode: 2.66 s
# 	Time updating the agent: 0.14 s
# Episode 1240 - reward: 26.30
# 	Time playing the episode: 2.64 s
# 	Time updating the agent: 0.13 s
# Episode 1250 - reward: 26.60
# 	Time playing the episode: 2.72 s
# 	Time updating the agent: 0.14 s
# Episode 1260 - reward: 26.90
# 	Time playing the episode: 2.67 s
# 	Time updating the agent: 0.13 s
# Episode 1270 - reward: 26.30
# 	Time playing the episode: 2.68 s
# 	Time updating the agent: 0.14 s
# Episode 1280 - reward: 25.90
# 	Time playing the episode: 2.76 s
# 	Time updating the agent: 0.14 s
# Episode 1290 - reward: 25.70
# 	Time playing the episode: 2.70 s
# 	Time updating the agent: 0.14 s
# Episode 1300 - reward: 26.40
# 	Time playing the episode: 2.80 s
# 	Time updating the agent: 0.17 s
# Episode 1310 - reward: 26.40
# 	Time playing the episode: 2.65 s
# 	Time updating the agent: 0.13 s
# Episode 1320 - reward: 25.50
# 	Time playing the episode: 2.68 s
# 	Time updating the agent: 0.14 s
# Episode 1330 - reward: 26.00
# 	Time playing the episode: 2.70 s
# 	Time updating the agent: 0.13 s
# Episode 1340 - reward: 25.90
# 	Time playing the episode: 2.71 s
# 	Time updating the agent: 0.14 s
# Episode 1350 - reward: 26.00
# 	Time playing the episode: 2.85 s
# 	Time updating the agent: 0.15 s
# Episode 1360 - reward: 26.20
# 	Time playing the episode: 2.55 s
# 	Time updating the agent: 0.13 s
# Episode 1370 - reward: 26.00
# 	Time playing the episode: 2.68 s
# 	Time updating the agent: 0.14 s
# Episode 1380 - reward: 25.60
# 	Time playing the episode: 2.84 s
# 	Time updating the agent: 0.16 s
# Episode 1390 - reward: 24.80
# 	Time playing the episode: 2.57 s
# 	Time updating the agent: 0.13 s
# Episode 1400 - reward: 25.60
# 	Time playing the episode: 2.60 s
# 	Time updating the agent: 0.15 s
# Episode 1410 - reward: 25.70
# 	Time playing the episode: 2.50 s
# 	Time updating the agent: 0.13 s
# Episode 1420 - reward: 25.70
# 	Time playing the episode: 2.67 s
# 	Time updating the agent: 0.14 s
# Episode 1430 - reward: 26.00
# 	Time playing the episode: 2.62 s
# 	Time updating the agent: 0.13 s
# Episode 1440 - reward: 26.30
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.13 s
# Episode 1450 - reward: 26.00
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.13 s
# Episode 1460 - reward: 26.20
# 	Time playing the episode: 2.48 s
# 	Time updating the agent: 0.13 s
# Episode 1470 - reward: 26.00
# 	Time playing the episode: 2.69 s
# 	Time updating the agent: 0.13 s
# Episode 1480 - reward: 26.00
# 	Time playing the episode: 2.64 s
# 	Time updating the agent: 0.13 s
# Episode 1490 - reward: 25.50
# 	Time playing the episode: 2.64 s
# 	Time updating the agent: 0.13 s
# Episode 1500 - reward: 26.30
# 	Time playing the episode: 2.58 s
# 	Time updating the agent: 0.14 s
# Episode 1510 - reward: 25.70
# 	Time playing the episode: 2.88 s
# 	Time updating the agent: 0.13 s
# Episode 1520 - reward: 25.50
# 	Time playing the episode: 2.62 s
# 	Time updating the agent: 0.13 s
# Episode 1530 - reward: 24.50
# 	Time playing the episode: 2.49 s
# 	Time updating the agent: 0.12 s
# Episode 1540 - reward: 26.10
# 	Time playing the episode: 2.52 s
# 	Time updating the agent: 0.13 s
# Episode 1550 - reward: 26.10
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.15 s
# Episode 1560 - reward: 25.60
# 	Time playing the episode: 2.73 s
# 	Time updating the agent: 0.13 s
# Episode 1570 - reward: 25.40
# 	Time playing the episode: 2.73 s
# 	Time updating the agent: 0.13 s
# Episode 1580 - reward: 26.00
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.14 s
# Episode 1590 - reward: 24.90
# 	Time playing the episode: 2.69 s
# 	Time updating the agent: 0.14 s
# Episode 1600 - reward: 27.10
# 	Time playing the episode: 2.53 s
# 	Time updating the agent: 0.13 s
# Episode 1610 - reward: 24.70
# 	Time playing the episode: 2.76 s
# 	Time updating the agent: 0.17 s
# Episode 1620 - reward: 25.00
# 	Time playing the episode: 2.59 s
# 	Time updating the agent: 0.13 s
# Episode 1630 - reward: 25.60
# 	Time playing the episode: 2.57 s
# 	Time updating the agent: 0.15 s
# Episode 1640 - reward: 25.80
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.14 s
# Episode 1650 - reward: 25.70
# 	Time playing the episode: 2.50 s
# 	Time updating the agent: 0.13 s
# Episode 1660 - reward: 25.10
# 	Time playing the episode: 2.57 s
# 	Time updating the agent: 0.13 s
# Episode 1670 - reward: 25.90
# 	Time playing the episode: 2.60 s
# 	Time updating the agent: 0.14 s
# Episode 1680 - reward: 25.50
# 	Time playing the episode: 2.59 s
# 	Time updating the agent: 0.15 s
# Episode 1690 - reward: 25.90
# 	Time playing the episode: 2.57 s
# 	Time updating the agent: 0.13 s
# Episode 1700 - reward: 26.00
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.13 s
# Episode 1710 - reward: 26.00
# 	Time playing the episode: 2.58 s
# 	Time updating the agent: 0.13 s
# Episode 1720 - reward: 25.40
# 	Time playing the episode: 2.73 s
# 	Time updating the agent: 0.13 s
# Episode 1730 - reward: 25.10
# 	Time playing the episode: 2.56 s
# 	Time updating the agent: 0.14 s
# Episode 1740 - reward: 25.50
# 	Time playing the episode: 2.59 s
# 	Time updating the agent: 0.13 s
# Episode 1750 - reward: 26.90
# 	Time playing the episode: 2.58 s
# 	Time updating the agent: 0.13 s
# Episode 1760 - reward: 25.40
# 	Time playing the episode: 2.49 s
# 	Time updating the agent: 0.12 s
# Episode 1770 - reward: 26.00
# 	Time playing the episode: 2.59 s
# 	Time updating the agent: 0.26 s
# Episode 1780 - reward: 26.10
# 	Time playing the episode: 2.51 s
# 	Time updating the agent: 0.12 s
# Episode 1790 - reward: 24.90
# 	Time playing the episode: 2.52 s
# 	Time updating the agent: 0.13 s
# Episode 1800 - reward: 25.90
# 	Time playing the episode: 2.56 s
# 	Time updating the agent: 0.13 s
# Episode 1810 - reward: 25.40
# 	Time playing the episode: 2.49 s
# 	Time updating the agent: 0.14 s
# Episode 1820 - reward: 25.40
# 	Time playing the episode: 2.79 s
# 	Time updating the agent: 0.15 s
# Episode 1830 - reward: 24.70
# 	Time playing the episode: 2.95 s
# 	Time updating the agent: 0.16 s
# Episode 1840 - reward: 25.80
# 	Time playing the episode: 2.79 s
# 	Time updating the agent: 0.14 s
# Episode 1850 - reward: 25.70
# 	Time playing the episode: 2.63 s
# 	Time updating the agent: 0.13 s
# Episode 1860 - reward: 26.80
# 	Time playing the episode: 2.77 s
# 	Time updating the agent: 0.14 s
# Episode 1870 - reward: 26.10
# 	Time playing the episode: 2.55 s
# 	Time updating the agent: 0.14 s
# Episode 1880 - reward: 24.70
# 	Time playing the episode: 2.53 s
# 	Time updating the agent: 0.13 s
# Episode 1890 - reward: 26.90
# 	Time playing the episode: 2.65 s
# 	Time updating the agent: 0.13 s
# Episode 1900 - reward: 26.10
# 	Time playing the episode: 2.64 s
# 	Time updating the agent: 0.17 s
# Episode 1910 - reward: 26.70
# 	Time playing the episode: 2.66 s
# 	Time updating the agent: 0.14 s
# Episode 1920 - reward: 27.00
# 	Time playing the episode: 2.62 s
# 	Time updating the agent: 0.13 s
# Episode 1930 - reward: 25.20
# 	Time playing the episode: 2.91 s
# 	Time updating the agent: 0.16 s
# Episode 1940 - reward: 24.90
# 	Time playing the episode: 2.64 s
# 	Time updating the agent: 0.16 s
# Episode 1950 - reward: 26.40
# 	Time playing the episode: 2.83 s
# 	Time updating the agent: 0.16 s
# Episode 1960 - reward: 25.60
# 	Time playing the episode: 2.70 s
# 	Time updating the agent: 0.13 s
# Episode 1970 - reward: 25.80
# 	Time playing the episode: 2.77 s
# 	Time updating the agent: 0.15 s
# Episode 1980 - reward: 25.70
# 	Time playing the episode: 2.75 s
# 	Time updating the agent: 0.13 s
# Episode 1990 - reward: 26.10
# 	Time playing the episode: 2.73 s
# 	Time updating the agent: 0.15 s
# Episode 2000 - reward: 25.80
# 	Time playing the episode: 3.17 s
# 	Time updating the agent: 0.18 s
# Episode 2010 - reward: 27.10
# 	Time playing the episode: 2.62 s
# 	Time updating the agent: 0.13 s
# Episode 2020 - reward: 25.80
# 	Time playing the episode: 2.63 s
# 	Time updating the agent: 0.13 s
# Episode 2030 - reward: 25.80
# 	Time playing the episode: 2.64 s
# 	Time updating the agent: 0.13 s
# Episode 2040 - reward: 26.20
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.13 s
# Episode 2050 - reward: 26.40
# 	Time playing the episode: 2.67 s
# 	Time updating the agent: 0.14 s
# Episode 2060 - reward: 26.50
# 	Time playing the episode: 2.59 s
# 	Time updating the agent: 0.15 s
# Episode 2070 - reward: 25.20
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.13 s
# Episode 2080 - reward: 25.50
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.13 s
# Episode 2090 - reward: 26.90
# 	Time playing the episode: 2.64 s
# 	Time updating the agent: 0.13 s
# Episode 2100 - reward: 26.40
# 	Time playing the episode: 2.62 s
# 	Time updating the agent: 0.13 s
# Episode 2110 - reward: 25.40
# 	Time playing the episode: 2.63 s
# 	Time updating the agent: 0.13 s
# Episode 2120 - reward: 25.40
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.14 s
# Episode 2130 - reward: 25.80
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.13 s
# Episode 2140 - reward: 26.50
# 	Time playing the episode: 2.62 s
# 	Time updating the agent: 0.13 s
# Episode 2150 - reward: 25.10
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.14 s
# Episode 2160 - reward: 24.60
# 	Time playing the episode: 2.62 s
# 	Time updating the agent: 0.13 s
# Episode 2170 - reward: 25.70
# 	Time playing the episode: 2.59 s
# 	Time updating the agent: 0.14 s
# Episode 2180 - reward: 25.30
# 	Time playing the episode: 2.64 s
# 	Time updating the agent: 0.14 s
# Episode 2190 - reward: 26.20
# 	Time playing the episode: 2.64 s
# 	Time updating the agent: 0.13 s
# Episode 2200 - reward: 25.20
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.13 s
# Episode 2210 - reward: 25.50
# 	Time playing the episode: 2.60 s
# 	Time updating the agent: 0.13 s
# Episode 2220 - reward: 26.40
# 	Time playing the episode: 2.90 s
# 	Time updating the agent: 0.19 s
# Episode 2230 - reward: 26.10
# 	Time playing the episode: 2.75 s
# 	Time updating the agent: 0.14 s
# Episode 2240 - reward: 26.20
# 	Time playing the episode: 2.73 s
# 	Time updating the agent: 0.13 s
# Episode 2250 - reward: 25.70
# 	Time playing the episode: 3.56 s
# 	Time updating the agent: 0.22 s
# Episode 2260 - reward: 25.60
# 	Time playing the episode: 2.97 s
# 	Time updating the agent: 0.15 s
# Episode 2270 - reward: 25.00
# 	Time playing the episode: 2.99 s
# 	Time updating the agent: 0.15 s
# Episode 2280 - reward: 25.90
# 	Time playing the episode: 3.00 s
# 	Time updating the agent: 0.17 s
# Episode 2290 - reward: 26.30
# 	Time playing the episode: 3.01 s
# 	Time updating the agent: 0.17 s
# Episode 2300 - reward: 25.70
# 	Time playing the episode: 3.07 s
# 	Time updating the agent: 0.16 s
# Episode 2310 - reward: 24.40
# 	Time playing the episode: 2.98 s
# 	Time updating the agent: 0.16 s
# Episode 2320 - reward: 25.70
# 	Time playing the episode: 3.01 s
# 	Time updating the agent: 0.15 s
# Episode 2330 - reward: 25.70
# 	Time playing the episode: 6.41 s
# 	Time updating the agent: 0.16 s
# Episode 2340 - reward: 27.70
# 	Time playing the episode: 3.02 s
# 	Time updating the agent: 0.15 s
# Episode 2350 - reward: 26.30
# 	Time playing the episode: 3.01 s
# 	Time updating the agent: 0.16 s
# Episode 2360 - reward: 25.50
# 	Time playing the episode: 2.99 s
# 	Time updating the agent: 0.16 s
# Episode 2370 - reward: 26.20
# 	Time playing the episode: 3.00 s
# 	Time updating the agent: 0.15 s
# Episode 2380 - reward: 24.50
# 	Time playing the episode: 3.01 s
# 	Time updating the agent: 0.16 s
# Episode 2390 - reward: 25.10
# 	Time playing the episode: 2.97 s
# 	Time updating the agent: 0.16 s
# Episode 2400 - reward: 25.20
# 	Time playing the episode: 2.97 s
# 	Time updating the agent: 0.15 s
# Episode 2410 - reward: 25.40
# 	Time playing the episode: 2.97 s
# 	Time updating the agent: 0.15 s
# Episode 2420 - reward: 25.10
# 	Time playing the episode: 2.93 s
# 	Time updating the agent: 0.16 s
# Episode 2430 - reward: 25.80
# 	Time playing the episode: 2.94 s
# 	Time updating the agent: 0.16 s
# Episode 2440 - reward: 25.20
# 	Time playing the episode: 3.04 s
# 	Time updating the agent: 0.16 s
# Episode 2450 - reward: 25.30
# 	Time playing the episode: 3.02 s
# 	Time updating the agent: 0.16 s
# Episode 2460 - reward: 25.00
# 	Time playing the episode: 2.98 s
# 	Time updating the agent: 0.16 s
# Episode 2470 - reward: 25.20
# 	Time playing the episode: 2.98 s
# 	Time updating the agent: 0.15 s
# Episode 2480 - reward: 25.90
# 	Time playing the episode: 2.94 s
# 	Time updating the agent: 0.15 s
# Episode 2490 - reward: 26.40
# 	Time playing the episode: 2.94 s
# 	Time updating the agent: 0.15 s
# Episode 2500 - reward: 25.90
# 	Time playing the episode: 3.02 s
# 	Time updating the agent: 0.15 s
# Episode 2510 - reward: 25.50
# 	Time playing the episode: 2.81 s
# 	Time updating the agent: 0.14 s
# Episode 2520 - reward: 25.30
# 	Time playing the episode: 2.86 s
# 	Time updating the agent: 0.13 s
# Episode 2530 - reward: 25.50
# 	Time playing the episode: 3.06 s
# 	Time updating the agent: 0.18 s
# Episode 2540 - reward: 26.10
# 	Time playing the episode: 2.81 s
# 	Time updating the agent: 0.14 s
# Episode 2550 - reward: 25.90
# 	Time playing the episode: 2.75 s
# 	Time updating the agent: 0.13 s
# Episode 2560 - reward: 27.30
# 	Time playing the episode: 2.74 s
# 	Time updating the agent: 0.14 s
# Episode 2570 - reward: 25.20
# 	Time playing the episode: 2.70 s
# 	Time updating the agent: 0.13 s
# Episode 2580 - reward: 25.20
# 	Time playing the episode: 2.62 s
# 	Time updating the agent: 0.13 s
# Episode 2590 - reward: 25.70
# 	Time playing the episode: 2.58 s
# 	Time updating the agent: 0.13 s
# Episode 2600 - reward: 25.70
# 	Time playing the episode: 2.60 s
# 	Time updating the agent: 0.13 s
# Episode 2610 - reward: 26.90
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.13 s
# Episode 2620 - reward: 25.90
# 	Time playing the episode: 2.65 s
# 	Time updating the agent: 0.13 s
# Episode 2630 - reward: 25.50
# 	Time playing the episode: 2.99 s
# 	Time updating the agent: 0.14 s
# Episode 2640 - reward: 27.50
# 	Time playing the episode: 2.89 s
# 	Time updating the agent: 0.18 s
# Episode 2650 - reward: 25.60
# 	Time playing the episode: 2.66 s
# 	Time updating the agent: 0.15 s
# Episode 2660 - reward: 26.70
# 	Time playing the episode: 2.77 s
# 	Time updating the agent: 0.19 s
# Episode 2670 - reward: 25.50
# 	Time playing the episode: 2.68 s
# 	Time updating the agent: 0.14 s
# Episode 2680 - reward: 24.20
# 	Time playing the episode: 2.91 s
# 	Time updating the agent: 0.14 s
# Episode 2690 - reward: 25.80
# 	Time playing the episode: 2.61 s
# 	Time updating the agent: 0.13 s
# Episode 2700 - reward: 25.00
# 	Time playing the episode: 2.62 s
# 	Time updating the agent: 0.13 s
# Episode 2710 - reward: 26.30
# 	Time playing the episode: 2.56 s
# 	Time updating the agent: 0.13 s
# Episode 2720 - reward: 26.00
# 	Time playing the episode: 2.57 s
# 	Time updating the agent: 0.13 s
# Episode 2730 - reward: 25.50
# 	Time playing the episode: 2.60 s
# 	Time updating the agent: 0.13 s
# Episode 2740 - reward: 27.20
# 	Time playing the episode: 2.64 s
# 	Time updating the agent: 0.13 s
# Episode 2750 - reward: 27.00
# 	Time playing the episode: 2.57 s
# 	Time updating the agent: 0.13 s
# Episode 2760 - reward: 26.70
# 	Time playing the episode: 2.60 s
# 	Time updating the agent: 0.13 s
# Episode 2770 - reward: 25.90
# 	Time playing the episode: 2.58 s
# 	Time updating the agent: 0.13 s
# Episode 2780 - reward: 25.80
# 	Time playing the episode: 2.55 s
# 	Time updating the agent: 0.13 s
# Episode 2790 - reward: 26.00
# 	Time playing the episode: 2.60 s
# 	Time updating the agent: 0.13 s
# Episode 2800 - reward: 25.00
# 	Time playing the episode: 2.63 s
# 	Time updating the agent: 0.13 s
# Episode 2810 - reward: 25.20
# 	Time playing the episode: 2.56 s
# 	Time updating the agent: 0.13 s
# Episode 2820 - reward: 25.30
# 	Time playing the episode: 2.59 s
# 	Time updating the agent: 0.13 s
# Episode 2830 - reward: 25.00
# 	Time playing the episode: 2.59 s
# 	Time updating the agent: 0.13 s
# Episode 2840 - reward: 25.70
# 	Time playing the episode: 2.60 s
# 	Time updating the agent: 0.13 s
# Episode 2850 - reward: 26.50
# 	Time playing the episode: 2.60 s
# 	Time updating the agent: 0.13 s
# Episode 2860 - reward: 26.00
# 	Time playing the episode: 2.62 s
# 	Time updating the agent: 0.13 s
# Episode 2870 - reward: 26.00
# 	Time playing the episode: 2.60 s
# 	Time updating the agent: 0.13 s
# Episode 2880 - reward: 25.40
# 	Time playing the episode: 2.59 s
# 	Time updating the agent: 0.13 s
# Episode 2890 - reward: 25.60
# 	Time playing the episode: 2.62 s
# 	Time updating the agent: 0.13 s
# Episode 2900 - reward: 26.00
# 	Time playing the episode: 2.62 s
# 	Time updating the agent: 0.13 s
# Episode 2910 - reward: 27.50
# 	Time playing the episode: 2.60 s
# 	Time updating the agent: 0.13 s
# Episode 2920 - reward: 25.40
# 	Time playing the episode: 2.60 s
# 	Time updating the agent: 0.13 s
# Episode 2930 - reward: 26.00
# 	Time playing the episode: 2.58 s
# 	Time updating the agent: 0.13 s
# Episode 2940 - reward: 24.70
# 	Time playing the episode: 2.57 s
# 	Time updating the agent: 0.13 s
# Episode 2950 - reward: 25.70
# 	Time playing the episode: 2.59 s
# 	Time updating the agent: 0.14 s
# Episode 2960 - reward: 25.00
# 	Time playing the episode: 2.64 s
# 	Time updating the agent: 0.16 s
# Episode 2970 - reward: 26.00
# 	Time playing the episode: 2.45 s
# 	Time updating the agent: 0.13 s
# Episode 2980 - reward: 26.40
# 	Time playing the episode: 2.47 s
# 	Time updating the agent: 0.13 s
# Episode 2990 - reward: 25.40
# 	Time playing the episode: 2.40 s
# 	Time updating the agent: 0.13 s
# Episode 3000 - reward: 25.20
# 	Time playing the episode: 2.53 s
# 	Time updating the agent: 0.13 s
# CPU times: user 1h 33min 9s, sys: 3min 19s, total: 1h 36min 28s
# Wall time: 2h 22min 38s

# %%
score, asymptotic_score, asymptotic_err, trained_agent, time_profile, losses = results

# %%
plot.plot_results(results, moving_average=100)
# Out:
# Average time for playing one episode: 2.71 s
# Average time for updating the agent: 0.14 s
# Asymptotic score: 25.828 +/- 1.850

# %%
save = False
keywords = ['agent1', str(len(score))+"-episodes","240-steps"] 

if save:
    save_dir = 'Results/MoveToBeacon/'
    ID = utils.save_session(save_dir, keywords, game_params, HPs, score, losses)
    torch.save(trained_agent, save_dir+"agent_"+ID)
else:
    print("Nothing saved")
    pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-21d61d49c15d> in <module>
#       1 save = False
# ----> 2 keywords = ['agent1', str(len(score))+"-episodes","240-steps"]
#       3
#       4 if save:
#       5     save_dir = 'Results/MoveToBeacon/'
#
# NameError: name 'score' is not defined

# %% [markdown]
# # Agent 2

# %%
reload(train)
reload(OheActorCritic)
# Out:
# <module 'RelationalModule.OheActorCritic' from '/home/nicola/Nicola_unipd/MasterThesis/SC2-RL/RelationalModule/OheActorCritic.py'>

# %%
SCREEN_RESOLUTION=16

replay_dict = dict(save_replay_episodes=1000,
                   replay_dir='Replays/',
                   replay_prefix='Agent2')

game_params = dict(feature_screen=SCREEN_RESOLUTION, # screen resolution in pixel
                      feature_minimap=SCREEN_RESOLUTION, # minimap resolution in pixel (smaller or equal to screen)
                      action_space="FEATURES") # either FEATURES or RGB - suggested: FEATURES

MAX_STEPS = 256
N_EPISODES = 1000

# %%
HPs = dict(action_space=3, map_size=SCREEN_RESOLUTION-2, lr=5e-4, 
           gamma=0.9, TD=True, twin=True, tau=0.3, n_steps=5, H=1e-3)
    
agent = OheActorCritic.MoveToBeaconOheA2C(**HPs)

# %%
# Init environment + play one episode + update agent

env = train.init_game(game_params, max_steps=MAX_STEPS, **replay_dict)

results = train.play_episode(agent, env, MAX_STEPS, coord_state=False)
rewards, log_probs, distributions, states, done, bootstrap = results

losses = agent.update(rewards, log_probs, distributions, states, done, bootstrap)
critic_loss, agent_loss, negative_entropy_term = losses

print("rewards: ", rewards.shape)
print("log_probs: ", len(log_probs))
print("distributions: ", len(distributions))
print("states: ", states.shape)
print("done: ", done.shape)
print("bootstrap: ", bootstrap.shape)
# Out:
# rewards:  (240,)
# log_probs:  240
# distributions:  240
# states:  (241, 3, 16, 16)
# done:  (240,)
# bootstrap:  (240,)

# %% [markdown]
# ## Training cycle

# %%
# %%time
results = train.train_SC2_agent(agent, game_params, N_EPISODES, MAX_STEPS, 
                                return_agent=True, coord_state=False, **replay_dict)
# Out:
# Episode 10 - reward: 22.10
# 	Time playing the episode: 3.59 s
# 	Time updating the agent: 3.45 s
# Episode 20 - reward: 18.70
# 	Time playing the episode: 3.59 s
# 	Time updating the agent: 3.44 s
# Episode 30 - reward: 21.70
# 	Time playing the episode: 3.69 s
# 	Time updating the agent: 3.43 s
# Episode 40 - reward: 24.50
# 	Time playing the episode: 3.75 s
# 	Time updating the agent: 3.49 s
# Episode 50 - reward: 25.00
# 	Time playing the episode: 3.77 s
# 	Time updating the agent: 3.70 s
# Episode 60 - reward: 24.40
# 	Time playing the episode: 3.73 s
# 	Time updating the agent: 3.45 s
# Episode 70 - reward: 25.50
# 	Time playing the episode: 3.76 s
# 	Time updating the agent: 3.40 s
# Episode 80 - reward: 25.60
# 	Time playing the episode: 3.72 s
# 	Time updating the agent: 3.48 s
# Episode 90 - reward: 25.30
# 	Time playing the episode: 3.74 s
# 	Time updating the agent: 3.42 s
# Episode 100 - reward: 26.10
# 	Time playing the episode: 3.73 s
# 	Time updating the agent: 3.54 s
# Episode 110 - reward: 25.70
# 	Time playing the episode: 3.89 s
# 	Time updating the agent: 3.86 s
# Episode 120 - reward: 25.80
# 	Time playing the episode: 3.76 s
# 	Time updating the agent: 3.42 s
# Episode 130 - reward: 24.80
# 	Time playing the episode: 3.76 s
# 	Time updating the agent: 3.43 s
# Episode 140 - reward: 25.20
# 	Time playing the episode: 3.78 s
# 	Time updating the agent: 3.46 s
# Episode 150 - reward: 24.80
# 	Time playing the episode: 3.76 s
# 	Time updating the agent: 3.46 s
# Episode 160 - reward: 26.40
# 	Time playing the episode: 3.73 s
# 	Time updating the agent: 3.43 s
# Episode 170 - reward: 25.30
# 	Time playing the episode: 3.75 s
# 	Time updating the agent: 3.41 s
# Episode 180 - reward: 25.50
# 	Time playing the episode: 3.78 s
# 	Time updating the agent: 3.45 s
# Episode 190 - reward: 26.70
# 	Time playing the episode: 3.79 s
# 	Time updating the agent: 3.45 s
# Episode 200 - reward: 24.70
# 	Time playing the episode: 3.71 s
# 	Time updating the agent: 3.45 s
# Episode 210 - reward: 26.30
# 	Time playing the episode: 3.94 s
# 	Time updating the agent: 4.31 s
# Episode 220 - reward: 25.50
# 	Time playing the episode: 4.03 s
# 	Time updating the agent: 3.56 s
# Episode 230 - reward: 26.10
# 	Time playing the episode: 3.82 s
# 	Time updating the agent: 3.63 s
# Episode 240 - reward: 26.50
# 	Time playing the episode: 3.81 s
# 	Time updating the agent: 3.45 s
# Episode 250 - reward: 25.00
# 	Time playing the episode: 3.78 s
# 	Time updating the agent: 3.53 s
# Episode 260 - reward: 26.10
# 	Time playing the episode: 3.76 s
# 	Time updating the agent: 3.58 s
# Episode 270 - reward: 26.20
# 	Time playing the episode: 4.55 s
# 	Time updating the agent: 5.45 s
# Episode 280 - reward: 26.10
# 	Time playing the episode: 3.77 s
# 	Time updating the agent: 3.43 s
# Episode 290 - reward: 26.20
# 	Time playing the episode: 3.91 s
# 	Time updating the agent: 3.86 s
# Episode 300 - reward: 24.90
# 	Time playing the episode: 3.84 s
# 	Time updating the agent: 3.72 s
# Episode 310 - reward: 25.60
# 	Time playing the episode: 3.94 s
# 	Time updating the agent: 3.64 s
# Episode 320 - reward: 25.40
# 	Time playing the episode: 3.89 s
# 	Time updating the agent: 3.46 s
# Episode 330 - reward: 25.80
# 	Time playing the episode: 3.78 s
# 	Time updating the agent: 3.46 s
# Episode 340 - reward: 26.00
# 	Time playing the episode: 4.00 s
# 	Time updating the agent: 3.41 s
# Episode 350 - reward: 25.90
# 	Time playing the episode: 3.84 s
# 	Time updating the agent: 3.50 s
# Episode 360 - reward: 26.60
# 	Time playing the episode: 3.82 s
# 	Time updating the agent: 3.52 s
# Episode 370 - reward: 26.00
# 	Time playing the episode: 3.82 s
# 	Time updating the agent: 3.48 s
# Episode 380 - reward: 25.60
# 	Time playing the episode: 3.84 s
# 	Time updating the agent: 3.48 s
# Episode 390 - reward: 24.70
# 	Time playing the episode: 3.85 s
# 	Time updating the agent: 3.67 s
# Episode 400 - reward: 25.90
# 	Time playing the episode: 3.84 s
# 	Time updating the agent: 3.52 s
# Episode 410 - reward: 25.30
# 	Time playing the episode: 3.81 s
# 	Time updating the agent: 3.60 s
# Episode 420 - reward: 26.40
# 	Time playing the episode: 3.81 s
# 	Time updating the agent: 3.51 s
# Episode 430 - reward: 25.70
# 	Time playing the episode: 3.84 s
# 	Time updating the agent: 3.53 s
# Episode 440 - reward: 26.10
# 	Time playing the episode: 3.79 s
# 	Time updating the agent: 3.54 s
# Episode 450 - reward: 24.60
# 	Time playing the episode: 3.81 s
# 	Time updating the agent: 3.48 s
# Episode 460 - reward: 26.10
# 	Time playing the episode: 3.77 s
# 	Time updating the agent: 3.63 s
# Episode 470 - reward: 26.70
# 	Time playing the episode: 3.78 s
# 	Time updating the agent: 3.60 s
# Episode 480 - reward: 25.20
# 	Time playing the episode: 3.74 s
# 	Time updating the agent: 3.52 s
# Episode 490 - reward: 25.40
# 	Time playing the episode: 3.76 s
# 	Time updating the agent: 3.50 s
# Episode 500 - reward: 25.60
# 	Time playing the episode: 3.79 s
# 	Time updating the agent: 3.64 s
# Episode 510 - reward: 25.40
# 	Time playing the episode: 3.87 s
# 	Time updating the agent: 3.51 s
# Episode 520 - reward: 25.70
# 	Time playing the episode: 3.82 s
# 	Time updating the agent: 3.57 s
# Episode 530 - reward: 26.60
# 	Time playing the episode: 3.84 s
# 	Time updating the agent: 3.47 s
# Episode 540 - reward: 25.90
# 	Time playing the episode: 3.78 s
# 	Time updating the agent: 3.72 s
# Episode 550 - reward: 25.60
# 	Time playing the episode: 3.82 s
# 	Time updating the agent: 3.54 s
# Episode 560 - reward: 25.60
# 	Time playing the episode: 3.77 s
# 	Time updating the agent: 3.51 s
# Episode 570 - reward: 25.20
# 	Time playing the episode: 3.80 s
# 	Time updating the agent: 3.52 s
# Episode 580 - reward: 25.80
# 	Time playing the episode: 3.78 s
# 	Time updating the agent: 3.50 s
# Episode 590 - reward: 25.80
# 	Time playing the episode: 3.81 s
# 	Time updating the agent: 3.50 s
# Episode 600 - reward: 26.50
# 	Time playing the episode: 3.77 s
# 	Time updating the agent: 3.53 s
# Episode 610 - reward: 25.90
# 	Time playing the episode: 3.84 s
# 	Time updating the agent: 3.48 s
# Episode 620 - reward: 26.30
# 	Time playing the episode: 3.78 s
# 	Time updating the agent: 3.53 s
# Episode 630 - reward: 26.80
# 	Time playing the episode: 3.75 s
# 	Time updating the agent: 3.50 s
# Episode 640 - reward: 25.80
# 	Time playing the episode: 3.87 s
# 	Time updating the agent: 3.63 s
# Episode 650 - reward: 25.30
# 	Time playing the episode: 3.78 s
# 	Time updating the agent: 3.48 s
# Episode 660 - reward: 24.50
# 	Time playing the episode: 3.84 s
# 	Time updating the agent: 3.60 s
# Episode 670 - reward: 26.50
# 	Time playing the episode: 3.83 s
# 	Time updating the agent: 3.49 s
# Episode 680 - reward: 25.20
# 	Time playing the episode: 3.83 s
# 	Time updating the agent: 3.59 s
# Episode 690 - reward: 27.00
# 	Time playing the episode: 3.82 s
# 	Time updating the agent: 3.55 s
# Episode 700 - reward: 26.20
# 	Time playing the episode: 3.78 s
# 	Time updating the agent: 3.50 s
# Episode 710 - reward: 24.90
# 	Time playing the episode: 3.79 s
# 	Time updating the agent: 3.49 s
# Episode 720 - reward: 25.40
# 	Time playing the episode: 3.86 s
# 	Time updating the agent: 3.62 s
# Episode 730 - reward: 26.40
# 	Time playing the episode: 3.82 s
# 	Time updating the agent: 3.78 s
# Episode 740 - reward: 26.00
# 	Time playing the episode: 3.81 s
# 	Time updating the agent: 3.52 s
# Episode 750 - reward: 25.90
# 	Time playing the episode: 3.86 s
# 	Time updating the agent: 3.61 s
# Episode 760 - reward: 26.30
# 	Time playing the episode: 3.81 s
# 	Time updating the agent: 3.60 s
# Episode 770 - reward: 25.10
# 	Time playing the episode: 3.83 s
# 	Time updating the agent: 3.62 s
# Episode 780 - reward: 26.00
# 	Time playing the episode: 3.85 s
# 	Time updating the agent: 3.59 s
# Episode 790 - reward: 25.70
# 	Time playing the episode: 3.84 s
# 	Time updating the agent: 4.22 s
# Episode 800 - reward: 25.70
# 	Time playing the episode: 4.02 s
# 	Time updating the agent: 3.61 s
# Episode 810 - reward: 25.20
# 	Time playing the episode: 3.82 s
# 	Time updating the agent: 4.08 s
# Episode 820 - reward: 26.10
# 	Time playing the episode: 3.97 s
# 	Time updating the agent: 3.60 s
# Episode 830 - reward: 26.60
# 	Time playing the episode: 3.83 s
# 	Time updating the agent: 3.79 s
# Episode 840 - reward: 25.60
# 	Time playing the episode: 3.89 s
# 	Time updating the agent: 3.63 s
# Episode 850 - reward: 25.80
# 	Time playing the episode: 3.84 s
# 	Time updating the agent: 3.58 s
# Episode 860 - reward: 25.20
# 	Time playing the episode: 3.76 s
# 	Time updating the agent: 3.65 s
# Episode 870 - reward: 26.50
# 	Time playing the episode: 3.80 s
# 	Time updating the agent: 3.98 s
# Episode 880 - reward: 26.40
# 	Time playing the episode: 3.95 s
# 	Time updating the agent: 3.79 s
# Episode 890 - reward: 25.60
# 	Time playing the episode: 4.02 s
# 	Time updating the agent: 3.60 s
# Episode 900 - reward: 26.80
# 	Time playing the episode: 3.83 s
# 	Time updating the agent: 3.72 s
# Episode 910 - reward: 25.70
# 	Time playing the episode: 3.89 s
# 	Time updating the agent: 3.58 s
# Episode 920 - reward: 26.10
# 	Time playing the episode: 3.72 s
# 	Time updating the agent: 3.64 s
# Episode 930 - reward: 26.30
# 	Time playing the episode: 4.13 s
# 	Time updating the agent: 4.00 s
# Episode 940 - reward: 26.00
# 	Time playing the episode: 3.75 s
# 	Time updating the agent: 3.46 s
# Episode 950 - reward: 26.10
# 	Time playing the episode: 4.08 s
# 	Time updating the agent: 3.86 s
# Episode 960 - reward: 26.70
# 	Time playing the episode: 6.93 s
# 	Time updating the agent: 4.51 s
# Episode 970 - reward: 25.50
# 	Time playing the episode: 4.38 s
# 	Time updating the agent: 4.08 s
# Episode 980 - reward: 26.40
# 	Time playing the episode: 3.80 s
# 	Time updating the agent: 3.64 s
# Episode 990 - reward: 25.10
# 	Time playing the episode: 3.85 s
# 	Time updating the agent: 3.52 s
# Episode 1000 - reward: 25.80
# 	Time playing the episode: 4.01 s
# 	Time updating the agent: 4.88 s
# CPU times: user 3h 4min 46s, sys: 2min 47s, total: 3h 7min 34s
# Wall time: 2h 4min 30s

# %%
score, asymptotic_score, asymptotic_err, trained_agent, time_profile, losses = results

# %%
plot.plot_results(results, moving_average=True)
# Out:
# Average time for playing one episode: 3.85 s
# Average time for updating the agent: 3.61 s
# Asymptotic score: 26.012 +/- 1.892

# %%
save = True
keywords = ['agent2', str(len(score))+"-episodes","240-steps"] 

if save:
    save_dir = 'Results/MoveToBeacon/'
    ID = utils.save_session(save_dir, keywords, game_params, HPs, score, losses)
    torch.save(trained_agent, save_dir+"agent_"+ID)
else:
    print("Nothing saved")
    pass
# Out:
# Save at Results/MoveToBeacon/S_agent2_1000-episodes_240-steps_WYWL

# %% [markdown]
# ## Scripted agent

# %%
from Utils import play_scripted_agent as scripted

# %%
reload(scripted)
# Out:
# <module 'Utils.play_scripted_agent' from '/home/nicola/Nicola_unipd/MasterThesis/SC2-RL/Utils/play_scripted_agent.py'>

# %%
MAX_STEPS = 256
N_EPISODES = 1000

# %%
scripted_results = scripted.evaluate_scripted_agent(N_EPISODES, MAX_STEPS)
# Out:
# Episode 10 / 1000
# Episode 20 / 1000
# Episode 30 / 1000
# Episode 40 / 1000
# Episode 50 / 1000
# Episode 60 / 1000
# Episode 70 / 1000
# Episode 80 / 1000
# Episode 90 / 1000
# Episode 100 / 1000
# Episode 110 / 1000
# Episode 120 / 1000
# Episode 130 / 1000
# Episode 140 / 1000
# Episode 150 / 1000
# Episode 160 / 1000
# Episode 170 / 1000
# Episode 180 / 1000
# Episode 190 / 1000
# Episode 200 / 1000
# Episode 210 / 1000
# Episode 220 / 1000
# Episode 230 / 1000
# Episode 240 / 1000
# Episode 250 / 1000
# Episode 260 / 1000
# Episode 270 / 1000
# Episode 280 / 1000
# Episode 290 / 1000
# Episode 300 / 1000
# Episode 310 / 1000
# Episode 320 / 1000
# Episode 330 / 1000
# Episode 340 / 1000
# Episode 350 / 1000
# Episode 360 / 1000
# Episode 370 / 1000
# Episode 380 / 1000
# Episode 390 / 1000
# Episode 400 / 1000
# Episode 410 / 1000
# Episode 420 / 1000
# Episode 430 / 1000
# Episode 440 / 1000
# Episode 450 / 1000
# Episode 460 / 1000
# Episode 470 / 1000
# Episode 480 / 1000
# Episode 490 / 1000
# Episode 500 / 1000
# Episode 510 / 1000
# Episode 520 / 1000
# Episode 530 / 1000
# Episode 540 / 1000
# Episode 550 / 1000
# Episode 560 / 1000
# Episode 570 / 1000
# Episode 580 / 1000
# Episode 590 / 1000
# Episode 600 / 1000
# Episode 610 / 1000
# Episode 620 / 1000
# Episode 630 / 1000
# Episode 640 / 1000
# Episode 650 / 1000
# Episode 660 / 1000
# Episode 670 / 1000
# Episode 680 / 1000
# Episode 690 / 1000
# Episode 700 / 1000
# Episode 710 / 1000
# Episode 720 / 1000
# Episode 730 / 1000
# Episode 740 / 1000
# Episode 750 / 1000
# Episode 760 / 1000
# Episode 770 / 1000
# Episode 780 / 1000
# Episode 790 / 1000
# Episode 800 / 1000
# Episode 810 / 1000
# Episode 820 / 1000
# Episode 830 / 1000
# Episode 840 / 1000
# Episode 850 / 1000
# Episode 860 / 1000
# Episode 870 / 1000
# Episode 880 / 1000
# Episode 890 / 1000
# Episode 900 / 1000
# Episode 910 / 1000
# Episode 920 / 1000
# Episode 930 / 1000
# Episode 940 / 1000
# Episode 950 / 1000
# Episode 960 / 1000
# Episode 970 / 1000
# Episode 980 / 1000
# Episode 990 / 1000
# Episode 1000 / 1000

# %%
save = False
mean_score, std_score, score = scripted_results
scripted_dict = dict(mean_score=mean_score,
                     std_score=std_score,
                     score=score,
                     MAX_STEPS=MAX_STEPS,
                     N_EPISODES=N_EPISODES)
save_dir = 'Results/MoveToBeacon/'
if save:
    np.save(save_dir+'scripted_agent_evaluation', scripted_dict)

# %%
print("Scripted agent score: %.2f +/- %.2f"%(mean_score, std_score))
# Out:
# Scripted agent score: 25.87 +/- 1.91
